# %%
import pandas as pd

import os
import re

from sklearn import preprocessing
from Bio import SeqIO

# %%
def read_csv_file(file_path):
    try:
        return pd.read_csv(file_path, delimiter=';', encoding='utf-8', low_memory=False)
    except pd.errors.ParserError:
        print(f"Error parsing {file_path}")
        return pd.DataFrame()

# %%
data_path = f'{os.getcwd()}/data/data_expression'
all_files = [os.path.join(data_path, file) for file in os.listdir(data_path) if file.endswith('.csv')]

df_list = [read_csv_file(file) for file in all_files]
df = pd.concat(df_list, ignore_index=True)

# %%
category_mappings = {}
multi_categories = ["Respiration", "Gram_St", "Chromosome", "Species"]
binary_categories = ["Oxidase", "Catalase"]

intersection = set(binary_categories).intersection(set(multi_categories))

while intersection:
    multi_categories.remove(intersection.pop())

le = preprocessing.LabelEncoder()
for category in multi_categories:
    df[category] = le.fit_transform(df[category])
    category_mappings[category] = dict(zip(le.classes_, le.transform(le.classes_)))


lb = preprocessing.LabelBinarizer()
for category in binary_categories:
    # Fit LabelBinarizer only on non-NaN values and transform them
    non_nan_mask = df[category].notna()
    encoded_values = lb.fit_transform(df.loc[non_nan_mask, category])

    # Convert the result to a DataFrame to match the original index
    encoded_df = pd.DataFrame(encoded_values, index=df[non_nan_mask].index, columns=[category])

    # Combine the encoded values with the original DataFrame, preserving NaNs
    df[category] = encoded_df[category]
    category_mappings[category] = dict(zip(le.classes_, le.transform(le.classes_)))

 
df.reset_index(drop=True, inplace=True)

# %%
# Extract and clean regions
df['Is_Complement'] = df['Region'].str.contains('complement')
df['Region_Clean'] = df['Region'].str.replace('complement\(|\)', '', regex=True)
df['Is_circular'] = df['Region_Clean'].str.contains('join')
df['Region_Clean'] = df['Region_Clean'].str.replace('join\(|\)', '', regex=True)

# Initialize dictionary to store results for each species
species_complements = {}

# Group by species
grouped = df.groupby('Species')

# Process each group
for species, group in grouped:
    regions = group.loc[~group['Is_Complement'], 'Region_Clean'].unique()
    complements = group.loc[group['Is_Complement'], 'Region_Clean'].unique()
    
    # It is important to check that there are no regions that are both complements and not complements!!!
    assert len([region for region in regions if region in complements]) == 0
    
    # Store results for this species
    species_complements[species] = {
        'Regions_without_complements': [region for region in regions if region not in complements],
        'Complements_only': [complement for complement in complements if complement not in regions]
    }

# Print the results
for species, results in species_complements.items():
    print(f"Species: {species}")
    print("  Regions without complements:", results['Regions_without_complements'])
    print("  Complements only:", results['Complements_only'])
    print()
# Out:
# /var/folders/24/jbn800492ks0n353ktq87jp00000gn/T/ipykernel_73615/2895689301.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Is_Complement'] = df['Region'].str.contains('complement')
# /var/folders/24/jbn800492ks0n353ktq87jp00000gn/T/ipykernel_73615/2895689301.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Region_Clean'] = df['Region'].str.replace('complement\(|\)', '', regex=True)
# /var/folders/24/jbn800492ks0n353ktq87jp00000gn/T/ipykernel_73615/2895689301.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Is_circular'] = df['Region_Clean'].str.contains('join')
# Species: 0
#   Regions without complements: ['6070..7080', '7132..8139', '8177..9859', '9879..10640', '15327..16208', '26536..27702', '33699..35090', '35782..37119', '38639..40225', '40248..41222', '41219..42136', '42148..43143', '43140..44156', '44289..45491', '45717..46631', '46663..46848', '46961..47887', '52915..54375', '54372..55487', '55583..58030', '59458..60354', '61645..62331', '62447..64039', '64079..64783', '64807..65067', '65098..67092', '67104..67559', '68738..69646', '69751..70503', '70512..71201', '71253..71987', '71993..73051', '73092..73997', '74540..75436', '75646..76809', '78304..79374', '79376..80263', '80279..81073', '81111..81440', '81437..82816', '82813..83985', '83982..85049', '85140..86078', '86455..87288', '88428..89408', '89449..91506', '91499..93229', '94245..95276', '95333..96388', '96385..97251', '97253..98053', '98053..99210', '99194..99502', '99499..100944', '100954..102117', '102114..102500', '108887..109801', '109927..110853', '111020..111631', '111789..112241', '112254..112823', '112828..113325', '114198..115406', '117557..118477', '119073..120893', '127334..129964', '134947..136086', '136086..137477', '140758..141087', '142431..143624', '154558..154890', '156050..156391', '156395..156823', '156975..157400', '157890..158276', '162910..164301', '164683..165435', '165565..166908', '166964..167434', '199389..200567', '200614..201585', '202553..203620', '204427..205125', '205203..206402', '212182..212526', '212607..212924', '219347..220675', '224757..226202', '226296..226502', '226571..226849', '227028..227327', '228331..229245', '229670..230146', '235161..236633', '236728..238224', '249031..249924', '253577..254965', '260568..261020', '262307..263467', '283570..284442', '286406..287176', '287216..287458', '287462..288850', '288847..289722', '289712..290701', '290855..292192', '299914..300777', '300874..301563', '301727..302656', '304074..306845', '307967..309124', '309225..310832', '311008..311232', '311271..312146', '312539..313336', '313421..313996', '314018..315052', '315066..315956', '315973..316578', '317007..317678', '317722..318525', '318589..319962', '319959..321350', '321471..322793', '322790..323851', '324519..326351', '328735..329214', '329278..330477', '330734..331621', '331809..333965', '333959..334912', '334909..335934', '335936..336979', '336976..337824', '337851..339188', '341012..341788', '341920..342828', '343120..343591', '345860..345967', '347030..347704', '347716..348228', '348230..348603', '348704..349279', '353613..354560', '355984..357051', '360318..361718', '361715..362761', '371323..371664', '371841..372530', '372530..373870', '374006..374335', '374366..375367', '375364..376545', '380206..380928', '380925..381545', '381701..383380', '383450..384874', '384904..386433', '386459..387676', '391363..391878', '391878..392603', '392717..395005', '395002..395997', '401613..402017', '402537..403268', '403348..403686', '403760..404101', '404098..404448', '406226..407758', '407877..409337', '409359..409838', '409850..410866', '417801..419042', '419046..420260', '420281..421651', '422670..423476', '423526..424119', '424137..425108', '425126..426298', '426298..427080', '427106..428335', '428364..429173', '429173..429835', '429852..430685', '430711..431616', '431708..431923', '432044..433345', '433369..434244', '434410..435399', '435407..436177', '436180..437193', '439770..440360', '440373..442838', '442849..443748', '443741..444388', '444515..445450', '445453..446886', '446883..448820', '449134..450168', '451989..453050', '456558..456797', '456794..457438', '459947..461839', '467599..467973', '468015..469316', '469313..470482', '470651..471454', '471518..472474', '474159..475061', '476094..477020', '477403..478599', '478663..479565', '479570..480616', '480631..481410', '481424..482113', '482139..483176', '483220..484044', '484041..485783', '485875..487029', '487059..487658', '488547..489428', '489562..490530', '490531..491196', '491198..491902', '491940..492932', '495924..496700', '496993..49854 ...
#   Complements only: ['1..400', '980..2143', '2164..3555', '3599..4984', '5049..5855', '10649..11650', '11802..13397', '13400..14611', '14617..15204', '16256..17260', '17253..18170', '18215..19027', '19036..19833', '19830..20519', '20516..22435', '24949..25155', '25387..26421', '27865..29391', '29388..29825', '29945..30943', '31056..32540', '32530..33207', '35195..35650', '37171..38523', '48181..49626', '49897..51582', '51631..51903', '51951..52322', '52367..52501', '58139..59311', '60406..61329', '67634..68566', '74094..74378', '77263..78105', '87362..88243', '93216..94013', '102515..103795', '103812..104762', '104773..105846', '105878..107407', '107404..108435', '113369..114046', '115464..116183', '116921..117448', '117445..117648', '118509..118979', '120999..121781', '121796..122623', '122658..123431', '123428..124486', '124620..127271', '129986..130867', '130967..131425', '131661..133685', '133789..134748', '137521..138258', '138239..138895', '138892..139560', '139589..140371', '141252..142217', '145478..146200', '146220..148790', '148780..149751', '149851..150864', '151847..153241', '154985..155941', '157431..157769', '158290..158991', '159004..159636', '159669..160193', '160202..160792', '160911..161861', '161956..162687', '167480..168643', '168690..170024', '170027..171118', '171153..172394', '172422..173306', '173452..175734', '175979..177004', '177001..177546', '177717..179369', '179379..180443', '180440..181666', '181695..182456', '182490..184637', '184674..185645', '185707..186048', '186045..187193', '187186..187956', '188082..189314', '189436..189846', '189917..190714', '190773..192788', '192970..194577', '194866..196047', '196081..197946', '197964..199142', '201753..202085', '202096..202479', '203723..204349', '206407..207366', '207345..208556', '208719..209351', '209438..210154', '210164..211864', '212988..213788', '213785..214660', '214674..215969', '216003..217058', '217181..217978', '218016..219029', '220839..222548', '222939..223916', '224108..224758', '227297..228217', '230231..230929', '230954..232561', '232673..233302', '233348..234811', '238257..239465', '239494..241221', '241229..242155', '242168..243139', '243296..244903', '245114..246484', '246477..247907', '247974..248861', '249952..251160', '251208..251681', '251790..252692', '252753..253166', '255260..255904', '256223..256666', '256679..257290', '257444..258298', '258323..259711', '259786..260427', '261511..262287', '263503..263892', '263997..264788', '264785..265384', '265457..265684', '265699..266067', '266083..266433', '266430..266834', '266837..267655', '267652..268392', '268461..269159', '269197..269784', '269798..270889', '270886..272190', '272236..272910', '272907..274187', '274190..274435', '274441..275253', '275250..276047', '276223..276852', '276891..277700', '277785..278285', '278299..279087', '279084..279920', '280206..281267', '281287..282264', '282278..283504', '284460..285101', '285230..286147', '292307..293773', '293782..298521', '298875..299678', '303043..303885', '306867..307673', '312302..312502', '316654..316875', '323879..324367', '326493..327512', '327693..328535', '339185..339640', '339800..340819', '343692..344368', '344697..345749', '346044..346640', '349345..350901', '350939..352075', '352261..353499', '354579..355541', '357082..358191', '358257..359087', '359150..360067', '362781..364223', '364207..365238', '365387..368572', '368589..369803', '369817..371070', '376533..378458', '378627..379736', '379763..380053', '387718..389340', '389481..390890', '395987..398047', '398064..399767', '399901..400224', '400235..401470', '402105..402314', '404472..405188', '405263..406000', '410888..411325', '411445..413154', '413151..414035', '414032..415009', '415022..416710', '416745..417572', '437376..437873', '437951..439498', '450186..450728', '450743..451846', '453109..455181', '455465..456385', '457722..458099', '458189..459718', '461862..462650', '462647..463678', '463691..464257', '464320..465840', '466114..466821', '466834..467553' ...
#
# Species: 1
#   Regions without complements: ['95..1492', '1590..2738', '2753..3835', '3888..6356', '6394..6786', '9866..10870', '11126..12133', '12476..13480', '13605..13940', '16178..17392', '23706..24305', '25685..27163', '27176..27319', '29975..31804', '32118..33407', '33486..34217', '40420..41520', '41523..44648', '44788..45165', '45270..46382', '47032..47853', '47905..48558', '50718..51620', '52069..53493', '58977..59435', '59548..60717', '60823..62088', '66219..66863', '66918..67856', '68034..69377', '70383..71438', '75433..76821', '76984..77667', '77846..79075', '80575..81327', '81324..81899', '82151..83827', '83915..85453', '85518..86930', '86982..88187', '88198..89118', '89373..91199', '91299..91937', '91961..92761', '93475..93759', '93968..94174', '94238..95305', '95292..98285', '98290..99990', '108980..110203', '110613..110948', '111202..111681', '112333..113547', '113698..114546', '114543..115394', '115613..116809', '120081..120914', '126282..127859', '127874..128389', '128555..131860', '131872..133620', '133642..134100', '134102..134458', '134555..135292', '135405..136130', '137752..138333', '138348..140231', '142063..143220', '147654..148004', '148163..148708', '148721..149488', '149517..151331', '153753..154190', '155897..156547', '159390..160334', '160572..161669', '161681..163129', '163167..164093', '164096..164950', '165011..166273', '166438..167613', '167724..168626', '169272..169964', '170215..172932', '172935..174914', '175063..175335', '175584..176159', '178603..179400', '179492..179857', '179993..181459', '181609..182946', '182957..183613', '183614..185314', '186562..187614', '187814..188116', '188145..189203', '189372..190664', '190661..191368', '193311..195260', '195955..196368', '198734..199384', '204270..204602', '204604..206319', '206489..207181', '207347..209314', '211247..212953', '216118..216720', '216724..217701', '217766..218119', '218172..218513', '219500..220582', '220729..222093', '222145..222726', '223851..224399', '224705..226147', '227864..229156', '229153..230601', '232604..233476', '233916..235214', '235219..236046', '236055..236477', '238703..239623', '240736..241479', '241504..241896', '244914..245465', '246048..246362', '247853..248410', '249413..249955', '250338..252215', '252970..254049', '254146..254745', '254791..255033', '257178..257816', '258729..259679', '259692..260321', '260358..260753', '261788..262339', '265976..266359', '272077..274425', '274727..276916', '279723..281384', '281563..282156', '283097..283495', '283550..284965', '284968..286185', '286175..289333', '289466..290422', '291053..292000', '297514..298515', '298738..299661', '299661..299993', '300005..301837', '301841..303340', '303349..304749', '304750..305868', '305929..306261', '306282..307088', '309823..310881', '310881..311522', '311519..312259', '312270..312797', '312860..315025', '315037..315606', '315635..316717', '316733..317608', '318063..322544', '322614..324035', '324211..325098', '325229..325819', '325841..326923', '326917..327477', '327823..328296', '328541..330169', '335246..336196', '336366..336839', '336839..337393', '337394..338395', '338392..339210', '339222..343076', '343087..343569', '343566..343991', '344084..344389', '344409..344957', '345003..345743', '345951..346319', '348612..349517', '349543..350313', '350523..350966', '354529..355938', '356034..356402', '357587..357952', '358322..359551', '364667..365137', '365274..365837', '367358..368635', '369049..370482', '371518..372789', '372934..374148', '374167..375198', '375198..376667', '376685..378028', '378041..379015', '380429..380740', '380776..382131', '384299..385201', '385237..385521', '390759..391943', '392116..393378', '393381..394178', '394311..395411', '395989..396636', '398789..401092', '404084..405988', '406111..406941', '407351..409198', '409602..410420', '410417..411196', '411196..411876', '411903..412544', '412556..412843', '414084..414665', '414680..415081', '417778..418593', '418673..419659', '422552..423424', '423531..424796', '431180..43 ...
#   Complements only: ['6870..7427', '7678..9609', '13998..14843', '14971..16098', '24363..25055', '27363..28667', '28664..29626', '34226..35116', '35196..36491', '36792..39476', '39647..40270', '46497..46847', '48599..49789', '49794..50597', '51604..51978', '53496..54524', '54563..55123', '55154..55399', '55409..55945', '55993..57027', '57168..57530', '57715..58452', '58624..58782', '62104..62943', '63229..63432', '63622..64341', '64378..64983', '64996..65889', '69387..69860', '71503..72282', '72582..73130', '73148..73780', '73767..75074', '79110..80222', '100659..102497', '102510..103874', '103891..104406', '104384..105301', '105317..105766', '105770..106240', '106252..107373', '107613..108902', '110189..110500', '111721..112164', '116879..118237', '118247..118957', '119213..119884', '120971..122338', '122445..123599', '123627..124937', '124951..125514', '125574..126113', '136197..137540', '140353..140856', '140853..141863', '143273..143998', '144121..145488', '145513..145836', '145833..146336', '146436..147401', '151323..152516', '152692..153603', '154228..154578', '155034..155858', '156598..158787', '159016..159228', '168724..169164', '176219..178375', '185359..186126', '191348..192328', '192441..193016', '195307..195849', '196462..197574', '197620..198357', '199427..200194', '200589..204086', '209373..210254', '212987..215821', '218563..219237', '222767..223090', '223087..223782', '226208..227707', '230706..231680', '231701..232327', '237320..238564', '239620..240507', '241942..242943', '243055..243957', '244406..244600', '245520..245936', '246467..246991', '247154..247372', '247400..247735', '248441..249274', '252271..252714', '255242..255931', '256064..257068', '257858..258616', '260787..261689', '262407..263138', '263233..263874', '263961..264509', '264663..265280', '265280..265873', '266914..267345', '267476..268990', '269182..270639', '270657..271421', '276984..277874', '278148..279425', '282256..282948', '290441..290779', '292407..293291', '293410..294828', '295193..296701', '296818..297117', '307106..309661', '330212..330676', '330921..331115', '331325..331708', '331829..333934', '334143..334421', '334494..335123', '346371..347345', '347427..348458', '350974..351834', '351925..352809', '352908..354140', '356447..356761', '356775..357362', '359589..361739', '361932..362507', '362623..363741', '363864..364508', '365887..366420', '366436..367230', '379077..379838', '382230..382661', '382756..383175', '383324..384190', '385595..386662', '386667..387299', '387343..389412', '389412..390389', '395481..395735', '396708..398531', '401138..401926', '402100..403050', '403178..403780', '412913..413926', '415084..415719', '415712..417757', '419703..422276', '424839..425786', '425913..426689', '426798..427235', '427321..428085', '428231..429778', '429822..431012', '447440..448612', '454483..454914', '454926..455135', '455176..457230', '457364..459781', '461097..463520', '464311..465003', '466483..467277', '468318..469565', '470499..471074', '471147..471860', '472018..472689', '473894..474370', '474380..475468', '475506..476957', '481565..482092', '482160..482765', '493973..494572', '503227..503883', '503901..504329', '504336..504989', '505160..505546', '505559..505987', '508862..509305', '509390..510064', '510075..510446', '510489..511823', '512837..514462', '515627..516106', '516121..517344', '517350..517853', '523942..525315', '525402..526595', '526947..527282', '529273..529767', '529803..530291', '530749..532620', '532644..533123', '533128..533430', '533465..534079', '534983..535894', '535956..536663', '538095..539057', '539069..540970', '541022..541351', '541450..542583', '542759..543328', '543415..544443', '544597..545634', '547175..547471', '547468..547689', '547699..548436', '548446..548799', '548787..549104', '549257..549808', '549874..550206', '550203..552941', '553035..553226', '553705..553920', '554045..554860', '554968..555162', '556668..556946', '556947..557147', '557144..557383', '557513..558826', '558827..559267', ' ...
#
# Species: 2
#   Regions without complements: []
#   Complements only: ['71..1034']
#
# Species: 3
#   Regions without complements: ['8023..8751']
#   Complements only: []
#
# Species: 4
#   Regions without complements: ['109057..109761']
#   Complements only: []
#
# Species: 5
#   Regions without complements: []
#   Complements only: ['1074446..1074982']
#
# Species: 6
#   Regions without complements: []
#   Complements only: ['1075121..1075531']
#
# Species: 7
#   Regions without complements: ['1075644..1076255']
#   Complements only: []
#
# Species: 8
#   Regions without complements: ['1076279..1077646']
#   Complements only: []
#
# Species: 9
#   Regions without complements: ['1077615..1077887']
#   Complements only: []
#
# Species: 10
#   Regions without complements: ['1077868..1078617']
#   Complements only: []
#
# Species: 11
#   Regions without complements: []
#   Complements only: ['1078731..1079138']
#
# Species: 12
#   Regions without complements: ['1079276..1080400']
#   Complements only: []
#
# Species: 13
#   Regions without complements: ['1080413..1081243']
#   Complements only: []
#
# Species: 14
#   Regions without complements: []
#   Complements only: ['1081884..1083263']
#
# Species: 15
#   Regions without complements: []
#   Complements only: ['109845..111302']
#
# Species: 16
#   Regions without complements: ['1083417..1084211']
#   Complements only: []
#
# Species: 17
#   Regions without complements: ['1084286..1085548']
#   Complements only: []
#
# Species: 18
#   Regions without complements: ['1085723..1086193']
#   Complements only: []
#
# Species: 19
#   Regions without complements: ['1086197..1086643']
#   Complements only: []
#
# Species: 20
#   Regions without complements: ['1086653..1087411']
#   Complements only: []
#
# Species: 21
#   Regions without complements: []
#   Complements only: ['1087499..1088272']
#
# Species: 22
#   Regions without complements: []
#   Complements only: ['1088348..1088875']
#
# Species: 23
#   Regions without complements: ['1089037..1090281']
#   Complements only: []
#
# Species: 24
#   Regions without complements: ['1090305..1090622']
#   Complements only: []
#
# Species: 25
#   Regions without complements: ['1090558..1090875']
#   Complements only: []
#
# Species: 26
#   Regions without complements: ['111608..112708']
#   Complements only: []
#
# Species: 27
#   Regions without complements: []
#   Complements only: ['1091257..1091964']
#
# Species: 28
#   Regions without complements: ['1092179..1092706']
#   Complements only: []
#
# Species: 29
#   Regions without complements: ['1092727..1094058']
#   Complements only: []
#
# Species: 30
#   Regions without complements: ['1094124..1095707']
#   Complements only: []
#
# Species: 31
#   Regions without complements: ['1095806..1096549']
#   Complements only: []
#
# Species: 32
#   Regions without complements: ['1096567..1097061']
#   Complements only: []
#
# Species: 33
#   Regions without complements: ['1097269..1097367']
#   Complements only: []
#
# Species: 34
#   Regions without complements: ['1097673..1099895']
#   Complements only: []
#
# Species: 35
#   Regions without complements: ['1099899..1100942']
#   Complements only: []
#
# Species: 36
#   Regions without complements: ['1101037..1102102']
#   Complements only: []
#
# Species: 37
#   Regions without complements: ['112769..115249']
#   Complements only: []
#
# Species: 38
#   Regions without complements: ['1102102..1103256']
#   Complements only: []
#
# Species: 39
#   Regions without complements: ['1103382..1103699']
#   Complements only: []
#
# Species: 40
#   Regions without complements: []
#   Complements only: ['1104050..1104535']
#
# Species: 41
#   Regions without complements: []
#   Complements only: ['1104575..1105039']
#
# Species: 42
#   Regions without complements: []
#   Complements only: ['1105041..1105826']
#
# Species: 43
#   Regions without complements: ['1105977..1106156']
#   Complements only: []
#
# Species: 44
#   Regions without complements: ['1106131..1106796']
#   Complements only: []
#
# Species: 45
#   Regions without complements: []
#   Complements only: ['1106861..1107493']
#
# Species: 46
#   Regions without complements: []
#   Complements only: ['1107519..1108388']
#
# Species: 47
#   Regions without complements: ['1108611..1109900']
#   Complements only: []
#
# Species: 48
#   Regions without complements: []
#   Complements only: ['115320..116099']
#
# Species: 49
#   Regions without complements: ['1109893..1111068']
#   Complements only: []
#
# Species: 50
#   Regions without complements: ['1111049..1111699']
#   Complements only: []
#
# Species: 51
#   Regions without complements: ['1111693..1112457']
#   Complements only: []
#
# Species: 52
#   Regions without complements: ['1112457..1113098']
#   Complements only: []
#
# Species: 53
#   Regions without complements: ['1113170..1113694']
#   Complements only: []
#
# Species: 54
#   Regions without complements: ['1113711..1113881']
#   Complements only: []
#
# Species: 55
#   Regions without complements: ['1113908..1114927']
#   Complements only: []
#
# Species: 56
#   Regions without complements: ['1114974..1115924']
#   Complements only: []
#
# Species: 57
#   Regions without complements: ['1116031..1116969']
#   Complements only: []
#
# Species: 58
#   Regions without complements: ['1116994..1117722']
#   Complements only: []
#
# Species: 59
#   Regions without complements: ['116329..117786']
#   Complements only: []
#
# Species: 60
#   Regions without complements: ['1117995..1118225']
#   Complements only: []
#
# Species: 61
#   Regions without complements: ['1118454..1119689']
#   Complements only: []
#
# Species: 62
#   Regions without complements: []
#   Complements only: ['1119814..1121076']
#
# Species: 63
#   Regions without complements: ['1121377..1122633']
#   Complements only: []
#
# Species: 64
#   Regions without complements: ['1122700..1123008']
#   Complements only: []
#
# Species: 65
#   Regions without complements: ['1123068..1123535']
#   Complements only: []
#
# Species: 66
#   Regions without complements: ['1123548..1125509']
#   Complements only: []
#
# Species: 67
#   Regions without complements: ['1125502..1126617']
#   Complements only: []
#
# Species: 68
#   Regions without complements: ['1126666..1127523']
#   Complements only: []
#
# Species: 69
#   Regions without complements: ['1127554..1128744']
#   Complements only: []
#
# Species: 70
#   Regions without complements: ['118001..118255']
#   Complements only: []
#
# Species: 71
#   Regions without complements: ['1128794..1129093']
#   Complements only: []
#
# Species: 72
#   Regions without complements: ['1129139..1129777']
#   Complements only: []
#
# Species: 73
#   Regions without complements: ['1129842..1130804']
#   Complements only: []
#
# Species: 74
#   Regions without complements: []
#   Complements only: ['1131013..1131231']
#
# Species: 75
#   Regions without complements: ['1131594..1132958']
#   Complements only: []
#
# Species: 76
#   Regions without complements: ['1133084..1134379']
#   Complements only: []
#
# Species: 77
#   Regions without complements: ['1134505..1135284']
#   Complements only: []
#
# Species: 78
#   Regions without complements: ['1135268..1135990']
#   Complements only: []
#
# Species: 79
#   Regions without complements: ['1136000..1136767']
#   Complements only: []
#
# Species: 80
#   Regions without complements: []
#   Complements only: ['1136772..1137059']
#
# Species: 81
#   Regions without complements: ['118252..118534']
#   Complements only: []
#
# Species: 82
#   Regions without complements: []
#   Complements only: ['1137062..1137424']
#
# Species: 83
#   Regions without complements: []
#   Complements only: ['1137421..1137798']
#
# Species: 84
#   Regions without complements: []
#   Complements only: ['1137802..1138470']
#
# Species: 85
#   Regions without complements: []
#   Complements only: ['1138550..1139275']
#
# Species: 86
#   Regions without complements: ['1139364..1139585']
#   Complements only: []
#
# Species: 87
#   Regions without complements: []
#   Complements only: ['1139646..1140374']
#
# Species: 88
#   Regions without complements: ['1140533..1141432']
#   Complements only: []
#
# Species: 89
#   Regions without complements: ['1141444..1142064']
#   Complements only: []
#
# Species: 90
#   Regions without complements: []
#   Complements only: ['1142175..1143833']
#
# Species: 91
#   Regions without complements: []
#   Complements only: ['1143826..1145574']
#
# Species: 92
#   Regions without complements: []
#   Complements only: ['118547..119332']
#
# Species: 93
#   Regions without complements: []
#   Complements only: ['1145744..1147066']
#
# Species: 94
#   Regions without complements: ['1147393..1147833']
#   Complements only: []
#
# Species: 95
#   Regions without complements: ['1147849..1148361']
#   Complements only: []
#
# Species: 96
#   Regions without complements: ['1148439..1149452']
#   Complements only: []
#
# Species: 97
#   Regions without complements: ['1149455..1150252']
#   Complements only: []
#
# Species: 98
#   Regions without complements: ['1150452..1150856']
#   Complements only: []
#
# Species: 99
#   Regions without complements: []
#   Complements only: ['1150894..1151907']
#
# Species: 100
#   Regions without complements: ['1152103..1152321']
#   Complements only: []
#
# Species: 101
#   Regions without complements: ['1152378..1152821']
#   Complements only: []
#
# Species: 102
#   Regions without complements: ['1153250..1155139']
#   Complements only: []
#
# Species: 103
#   Regions without complements: []
#   Complements only: ['119493..119885']
#
# Species: 104
#   Regions without complements: []
#   Complements only: ['1155411..1156112']
#
# Species: 105
#   Regions without complements: ['1156419..1156781']
#   Complements only: []
#
# Species: 106
#   Regions without complements: ['1156840..1157457']
#   Complements only: []
#
# Species: 107
#   Regions without complements: ['1157569..1157946']
#   Complements only: []
#
# Species: 108
#   Regions without complements: ['1157971..1158759']
#   Complements only: []
#
# Species: 109
#   Regions without complements: ['1158811..1159065']
#   Complements only: []
#
# Species: 110
#   Regions without complements: ['1159115..1159585']
#   Complements only: []
#
# Species: 111
#   Regions without complements: ['1159599..1160147']
#   Complements only: []
#
# Species: 112
#   Regions without complements: ['1160160..1161701']
#   Complements only: []
#
# Species: 113
#   Regions without complements: ['1161717..1162586']
#   Complements only: []
#
# Species: 114
#   Regions without complements: []
#   Complements only: ['8841..10415']
#
# Species: 115
#   Regions without complements: []
#   Complements only: ['119902..120330']
#
# Species: 116
#   Regions without complements: ['1162603..1163976']
#   Complements only: []
#
# Species: 117
#   Regions without complements: ['1164018..1164446']
#   Complements only: []
#
# Species: 118
#   Regions without complements: []
#   Complements only: ['1164507..1165553']
#
# Species: 119
#   Regions without complements: ['1165558..1165809']
#   Complements only: []
#
# Species: 120
#   Regions without complements: []
#   Complements only: ['1165718..1166632']
#
# Species: 121
#   Regions without complements: []
#   Complements only: ['1166629..1167759']
#
# Species: 122
#   Regions without complements: ['1167845..1169215']
#   Complements only: []
#
# Species: 123
#   Regions without complements: []
#   Complements only: ['1169347..1170438']
#
# Species: 124
#   Regions without complements: []
#   Complements only: ['1170576..1171325']
#
# Species: 125
#   Regions without complements: []
#   Complements only: ['1171353..1172024']
#
# Species: 126
#   Regions without complements: []
#   Complements only: ['120572..121168']
#
# Species: 127
#   Regions without complements: ['1172330..1173178']
#   Complements only: []
#
# Species: 128
#   Regions without complements: ['1173232..1173531']
#   Complements only: []
#
# Species: 129
#   Regions without complements: ['1173573..1173908']
#   Complements only: []
#
# Species: 130
#   Regions without complements: []
#   Complements only: ['1174337..1174789']
#
# Species: 131
#   Regions without complements: ['1174830..1176098']
#   Complements only: []
#
# Species: 132
#   Regions without complements: ['1176139..1176297']
#   Complements only: []
#
# Species: 133
#   Regions without complements: ['1176450..1178532']
#   Complements only: []
#
# Species: 134
#   Regions without complements: ['1178695..1180107']
#   Complements only: []
#
# Species: 135
#   Regions without complements: ['1180097..1183063']
#   Complements only: []
#
# Species: 136
#   Regions without complements: ['1183067..1183648']
#   Complements only: []
#
# Species: 137
#   Regions without complements: []
#   Complements only: ['121181..123160']
#
# Species: 138
#   Regions without complements: ['1183658..1184291']
#   Complements only: []
#
# Species: 139
#   Regions without complements: ['1184335..1184541']
#   Complements only: []
#
# Species: 140
#   Regions without complements: ['1185056..1185382']
#   Complements only: []
#
# Species: 141
#   Regions without complements: ['1185566..1185805']
#   Complements only: []
#
# Species: 142
#   Regions without complements: ['1185730..1186902']
#   Complements only: []
#
# Species: 143
#   Regions without complements: ['1186909..1189713']
#   Complements only: []
#
# Species: 144
#   Regions without complements: ['1189717..1190583']
#   Complements only: []
#
# Species: 145
#   Regions without complements: []
#   Complements only: ['1190768..1190947']
#
# Species: 146
#   Regions without complements: []
#   Complements only: ['1190978..1191169']
#
# Species: 147
#   Regions without complements: ['1191155..1191706']
#   Complements only: []
#
# Species: 148
#   Regions without complements: []
#   Complements only: ['123160..126825']
#
# Species: 149
#   Regions without complements: []
#   Complements only: ['1191968..1192162']
#
# Species: 150
#   Regions without complements: []
#   Complements only: ['1192146..1192583']
#
# Species: 151
#   Regions without complements: []
#   Complements only: ['1193036..1193569']
#
# Species: 152
#   Regions without complements: []
#   Complements only: ['1193603..1194196']
#
# Species: 153
#   Regions without complements: []
#   Complements only: ['1194574..1194769']
#
# Species: 154
#   Regions without complements: ['1195107..1195964']
#   Complements only: []
#
# Species: 155
#   Regions without complements: []
#   Complements only: ['1196053..1197687']
#
# Species: 156
#   Regions without complements: []
#   Complements only: ['1197807..1198097']
#
# Species: 157
#   Regions without complements: []
#   Complements only: ['1198184..1198666']
#
# Species: 158
#   Regions without complements: ['1198896..1200314']
#   Complements only: []
#
# Species: 159
#   Regions without complements: []
#   Complements only: ['126896..127252']
#
# Species: 160
#   Regions without complements: ['1200495..1201532']
#   Complements only: []
#
# Species: 161
#   Regions without complements: []
#   Complements only: ['1202201..1203037']
#
# Species: 162
#   Regions without complements: []
#   Complements only: ['1203053..1203856']
#
# Species: 163
#   Regions without complements: []
#   Complements only: ['1203868..1204866']
#
# Species: 164
#   Regions without complements: ['1205183..1206607']
#   Complements only: []
#
# Species: 165
#   Regions without complements: ['1206802..1208205']
#   Complements only: []
#
# Species: 166
#   Regions without complements: ['1208229..1209020']
#   Complements only: []
#
# Species: 167
#   Regions without complements: ['1209017..1209769']
#   Complements only: []
#
# Species: 168
#   Regions without complements: ['1209817..1212750']
#   Complements only: []
#
# Species: 169
#   Regions without complements: ['1212760..1213647']
#   Complements only: []
#
# Species: 170
#   Regions without complements: []
#   Complements only: ['127677..128207']
#
# Species: 171
#   Regions without complements: ['1213649..1214842']
#   Complements only: []
#
# Species: 172
#   Regions without complements: ['1214875..1215909']
#   Complements only: []
#
# Species: 173
#   Regions without complements: ['1215998..1217170']
#   Complements only: []
#
# Species: 174
#   Regions without complements: ['1217172..1218263']
#   Complements only: []
#
# Species: 175
#   Regions without complements: ['1218274..1219692']
#   Complements only: []
#
# Species: 176
#   Regions without complements: []
#   Complements only: ['1219738..1220913']
#
# Species: 177
#   Regions without complements: []
#   Complements only: ['1221028..1222440']
#
# Species: 178
#   Regions without complements: []
#   Complements only: ['1222427..1223623']
#
# Species: 179
#   Regions without complements: []
#   Complements only: ['1223712..1224839']
#
# Species: 180
#   Regions without complements: []
#   Complements only: ['1224843..1226354']
#
# Species: 181
#   Regions without complements: []
#   Complements only: ['128350..130134']
#
# Species: 182
#   Regions without complements: []
#   Complements only: ['1226414..1227412']
#
# Species: 183
#   Regions without complements: ['1227670..1228989']
#   Complements only: []
#
# Species: 184
#   Regions without complements: ['1229039..1230016']
#   Complements only: []
#
# Species: 185
#   Regions without complements: ['1230038..1230511']
#   Complements only: []
#
# Species: 186
#   Regions without complements: ['1231130..1231393']
#   Complements only: []
#
# Species: 187
#   Regions without complements: ['1231755..1231943']
#   Complements only: []
#
# Species: 188
#   Regions without complements: ['1231982..1232617']
#   Complements only: []
#
# Species: 189
#   Regions without complements: []
#   Complements only: ['1232684..1233532']
#
# Species: 190
#   Regions without complements: []
#   Complements only: ['1233717..1234031']
#
# Species: 191
#   Regions without complements: []
#   Complements only: ['1234047..1235072']
#
# Species: 192
#   Regions without complements: ['130281..130727']
#   Complements only: []
#
# Species: 193
#   Regions without complements: []
#   Complements only: ['1235087..1236790']
#
# Species: 194
#   Regions without complements: ['1237066..1237350']
#   Complements only: []
#
# Species: 195
#   Regions without complements: ['1237384..1239870']
#   Complements only: []
#
# Species: 196
#   Regions without complements: ['1239942..1240757']
#   Complements only: []
#
# Species: 197
#   Regions without complements: ['1240757..1241638']
#   Complements only: []
#
# Species: 198
#   Regions without complements: ['1241676..1242125']
#   Complements only: []
#
# Species: 199
#   Regions without complements: ['1242139..1242774']
#   Complements only: []
#
# Species: 200
#   Regions without complements: []
#   Complements only: ['1242869..1244764']
#
# Species: 201
#   Regions without complements: []
#   Complements only: ['1244882..1245925']
#
# Species: 202
#   Regions without complements: []
#   Complements only: ['1245945..1247072']
#
# Species: 203
#   Regions without complements: []
#   Complements only: ['130794..131003']
#
# Species: 204
#   Regions without complements: []
#   Complements only: ['1247242..1248168']
#
# Species: 205
#   Regions without complements: ['1248448..1249224']
#   Complements only: []
#
# Species: 206
#   Regions without complements: ['1249251..1251065']
#   Complements only: []
#
# Species: 207
#   Regions without complements: ['1251274..1251546']
#   Complements only: []
#
# Species: 208
#   Regions without complements: []
#   Complements only: ['1251452..1252627']
#
# Species: 209
#   Regions without complements: []
#   Complements only: ['1252648..1254939']
#
# Species: 210
#   Regions without complements: []
#   Complements only: ['1254921..1255559']
#
# Species: 211
#   Regions without complements: []
#   Complements only: ['1255570..1256964']
#
# Species: 212
#   Regions without complements: []
#   Complements only: ['1257358..1258602']
#
# Species: 213
#   Regions without complements: []
#   Complements only: ['1258633..1259361']
#
# Species: 214
#   Regions without complements: []
#   Complements only: ['131194..131358']
#
# Species: 215
#   Regions without complements: []
#   Complements only: ['1259411..1259854']
#
# Species: 216
#   Regions without complements: []
#   Complements only: ['1259847..1261070']
#
# Species: 217
#   Regions without complements: []
#   Complements only: ['1261079..1261558']
#
# Species: 218
#   Regions without complements: []
#   Complements only: ['1261688..1263961']
#
# Species: 219
#   Regions without complements: []
#   Complements only: ['1263968..1264552']
#
# Species: 220
#   Regions without complements: []
#   Complements only: ['1264549..1264995']
#
# Species: 221
#   Regions without complements: []
#   Complements only: ['1264992..1265918']
#
# Species: 222
#   Regions without complements: []
#   Complements only: ['1265915..1266637']
#
# Species: 223
#   Regions without complements: []
#   Complements only: ['1266637..1267998']
#
# Species: 224
#   Regions without complements: []
#   Complements only: ['1267995..1268540']
#
# Species: 225
#   Regions without complements: []
#   Complements only: ['10464..11429']
#
# Species: 226
#   Regions without complements: []
#   Complements only: ['131409..132122']
#
# Species: 227
#   Regions without complements: []
#   Complements only: ['1268566..1270233']
#
# Species: 228
#   Regions without complements: []
#   Complements only: ['1270233..1270484']
#
# Species: 229
#   Regions without complements: []
#   Complements only: ['1270487..1270750']
#
# Species: 230
#   Regions without complements: []
#   Complements only: ['1270728..1271516']
#
# Species: 231
#   Regions without complements: []
#   Complements only: ['1271501..1272244']
#
# Species: 232
#   Regions without complements: []
#   Complements only: ['1272274..1272597']
#
# Species: 233
#   Regions without complements: ['1272625..1273050']
#   Complements only: []
#
# Species: 234
#   Regions without complements: []
#   Complements only: ['1273152..1273865']
#
# Species: 235
#   Regions without complements: []
#   Complements only: ['1273880..1274770']
#
# Species: 236
#   Regions without complements: []
#   Complements only: ['1274780..1275604']
#
# Species: 237
#   Regions without complements: []
#   Complements only: ['132119..132433']
#
# Species: 238
#   Regions without complements: []
#   Complements only: ['1275683..1275862']
#
# Species: 239
#   Regions without complements: []
#   Complements only: ['1275862..1276890']
#
# Species: 240
#   Regions without complements: ['1277073..1277573']
#   Complements only: []
#
# Species: 241
#   Regions without complements: []
#   Complements only: ['1277674..1280244']
#
# Species: 242
#   Regions without complements: ['1280407..1281090']
#   Complements only: []
#
# Species: 243
#   Regions without complements: []
#   Complements only: ['1281165..1282277']
#
# Species: 244
#   Regions without complements: []
#   Complements only: ['1282461..1283273']
#
# Species: 245
#   Regions without complements: ['1283419..1284105']
#   Complements only: []
#
# Species: 246
#   Regions without complements: ['1284217..1284801']
#   Complements only: []
#
# Species: 247
#   Regions without complements: []
#   Complements only: ['1284988..1285149']
#
# Species: 248
#   Regions without complements: ['132541..133323']
#   Complements only: []
#
# Species: 249
#   Regions without complements: []
#   Complements only: ['1285298..1286689']
#
# Species: 250
#   Regions without complements: ['1286827..1288461']
#   Complements only: []
#
# Species: 251
#   Regions without complements: []
#   Complements only: ['1288530..1290611']
#
# Species: 252
#   Regions without complements: []
#   Complements only: ['1290634..1292502']
#
# Species: 253
#   Regions without complements: []
#   Complements only: ['1292666..1292797']
#
# Species: 254
#   Regions without complements: []
#   Complements only: ['1292821..1293240']
#
# Species: 255
#   Regions without complements: []
#   Complements only: ['1293281..1293589']
#
# Species: 256
#   Regions without complements: []
#   Complements only: ['1293629..1293889']
#
# Species: 257
#   Regions without complements: []
#   Complements only: ['1293939..1294844']
#
# Species: 258
#   Regions without complements: []
#   Complements only: ['1294989..1295198']
#
# Species: 259
#   Regions without complements: ['133332..134171']
#   Complements only: []
#
# Species: 260
#   Regions without complements: []
#   Complements only: ['1295212..1295826']
#
# Species: 261
#   Regions without complements: []
#   Complements only: ['1295860..1296699']
#
# Species: 262
#   Regions without complements: []
#   Complements only: ['1296701..1297318']
#
# Species: 263
#   Regions without complements: []
#   Complements only: ['1297329..1299750']
#
# Species: 264
#   Regions without complements: []
#   Complements only: ['1300140..1300241']
#
# Species: 265
#   Regions without complements: []
#   Complements only: ['1300256..1303057']
#
# Species: 266
#   Regions without complements: ['1303274..1303837']
#   Complements only: []
#
# Species: 267
#   Regions without complements: ['1303941..1304171']
#   Complements only: []
#
# Species: 268
#   Regions without complements: ['1304181..1306196']
#   Complements only: []
#
# Species: 269
#   Regions without complements: []
#   Complements only: ['1306712..1307092']
#
# Species: 270
#   Regions without complements: []
#   Complements only: ['134223..135473']
#
# Species: 271
#   Regions without complements: ['1307220..1307822']
#   Complements only: []
#
# Species: 272
#   Regions without complements: ['1307822..1308427']
#   Complements only: []
#
# Species: 273
#   Regions without complements: ['1308430..1308915']
#   Complements only: []
#
# Species: 274
#   Regions without complements: ['1309127..1309633']
#   Complements only: []
#
# Species: 275
#   Regions without complements: ['1310005..1311334']
#   Complements only: []
#
# Species: 276
#   Regions without complements: ['1311321..1313264']
#   Complements only: []
#
# Species: 277
#   Regions without complements: ['1313554..1314684']
#   Complements only: []
#
# Species: 278
#   Regions without complements: ['1314748..1315176']
#   Complements only: []
#
# Species: 279
#   Regions without complements: ['1315253..1317454']
#   Complements only: []
#
# Species: 280
#   Regions without complements: ['1317454..1318608']
#   Complements only: []
#
# Species: 281
#   Regions without complements: []
#   Complements only: ['135466..136062']
#
# Species: 282
#   Regions without complements: ['1318647..1319852']
#   Complements only: []
#
# Species: 283
#   Regions without complements: []
#   Complements only: ['1320293..1320788']
#
# Species: 284
#   Regions without complements: []
#   Complements only: ['1321458..1321967']
#
# Species: 285
#   Regions without complements: []
#   Complements only: ['1321954..1322160']
#
# Species: 286
#   Regions without complements: []
#   Complements only: ['1322150..1322521']
#
# Species: 287
#   Regions without complements: []
#   Complements only: ['1322514..1323350']
#
# Species: 288
#   Regions without complements: []
#   Complements only: ['1323687..1324112']
#
# Species: 289
#   Regions without complements: []
#   Complements only: ['1324184..1324948']
#
# Species: 290
#   Regions without complements: []
#   Complements only: ['1324945..1325220']
#
# Species: 291
#   Regions without complements: []
#   Complements only: ['1325242..1325625']
#
# Species: 292
#   Regions without complements: []
#   Complements only: ['136019..137359']
#
# Species: 293
#   Regions without complements: []
#   Complements only: ['1325719..1326030']
#
# Species: 294
#   Regions without complements: []
#   Complements only: ['1326055..1326507']
#
# Species: 295
#   Regions without complements: []
#   Complements only: ['1326521..1326781']
#
# Species: 296
#   Regions without complements: []
#   Complements only: ['1326792..1327001']
#
# Species: 297
#   Regions without complements: []
#   Complements only: ['1327188..1327964']
#
# Species: 298
#   Regions without complements: []
#   Complements only: ['1327974..1328645']
#
# Species: 299
#   Regions without complements: []
#   Complements only: ['1328819..1330063']
#
# Species: 300
#   Regions without complements: []
#   Complements only: ['1330959..1331186']
#
# Species: 301
#   Regions without complements: []
#   Complements only: ['1331183..1333915']
#
# Species: 302
#   Regions without complements: []
#   Complements only: ['1334021..1334638']
#
# Species: 303
#   Regions without complements: ['137536..137911']
#   Complements only: []
#
# Species: 304
#   Regions without complements: ['1334719..1336644']
#   Complements only: []
#
# Species: 305
#   Regions without complements: ['1336792..1337850']
#   Complements only: []
#
# Species: 306
#   Regions without complements: ['1337932..1338390']
#   Complements only: []
#
# Species: 307
#   Regions without complements: ['1338463..1338852']
#   Complements only: []
#
# Species: 308
#   Regions without complements: []
#   Complements only: ['1338921..1340918']
#
# Species: 309
#   Regions without complements: []
#   Complements only: ['1341051..1342004']
#
# Species: 310
#   Regions without complements: ['1348261..1349194']
#   Complements only: []
#
# Species: 311
#   Regions without complements: []
#   Complements only: ['1349423..1350208']
#
# Species: 312
#   Regions without complements: []
#   Complements only: ['1350469..1350570']
#
# Species: 313
#   Regions without complements: []
#   Complements only: ['1351360..1352937']
#
# Species: 314
#   Regions without complements: ['137953..138711']
#   Complements only: []
#
# Species: 315
#   Regions without complements: []
#   Complements only: ['1352954..1353532']
#
# Species: 316
#   Regions without complements: []
#   Complements only: ['1353598..1354173']
#
# Species: 317
#   Regions without complements: []
#   Complements only: ['1354187..1354948']
#
# Species: 318
#   Regions without complements: []
#   Complements only: ['1354938..1355804']
#
# Species: 319
#   Regions without complements: []
#   Complements only: ['1355801..1356688']
#
# Species: 320
#   Regions without complements: []
#   Complements only: ['1356688..1357968']
#
# Species: 321
#   Regions without complements: []
#   Complements only: ['1357982..1359106']
#
# Species: 322
#   Regions without complements: []
#   Complements only: ['1359122..1359625']
#
# Species: 323
#   Regions without complements: []
#   Complements only: ['1359622..1361004']
#
# Species: 324
#   Regions without complements: []
#   Complements only: ['1361006..1361830']
#
# Species: 325
#   Regions without complements: []
#   Complements only: ['138740..139861']
#
# Species: 326
#   Regions without complements: []
#   Complements only: ['1361882..1362310']
#
# Species: 327
#   Regions without complements: []
#   Complements only: ['1362326..1362556']
#
# Species: 328
#   Regions without complements: []
#   Complements only: ['1362648..1362875']
#
# Species: 329
#   Regions without complements: ['1363395..1363643']
#   Complements only: []
#
# Species: 330
#   Regions without complements: ['1363631..1364095']
#   Complements only: []
#
# Species: 331
#   Regions without complements: ['1364257..1364958']
#   Complements only: []
#
# Species: 332
#   Regions without complements: ['1364962..1366887']
#   Complements only: []
#
# Species: 333
#   Regions without complements: []
#   Complements only: ['1367165..1367922']
#
# Species: 334
#   Regions without complements: ['1368429..1371887']
#   Complements only: []
#
# Species: 335
#   Regions without complements: ['1371989..1372573']
#   Complements only: []
#
# Species: 336
#   Regions without complements: ['11673..13190']
#   Complements only: []
#
# Species: 337
#   Regions without complements: ['140235..141233']
#   Complements only: []
#
# Species: 338
#   Regions without complements: ['1372714..1373448']
#   Complements only: []
#
# Species: 339
#   Regions without complements: ['1373469..1374188']
#   Complements only: []
#
# Species: 340
#   Regions without complements: ['1374193..1374855']
#   Complements only: []
#
# Species: 341
#   Regions without complements: ['1374858..1375541']
#   Complements only: []
#
# Species: 342
#   Regions without complements: ['1376083..1377681']
#   Complements only: []
#
# Species: 343
#   Regions without complements: ['1377945..1378403']
#   Complements only: []
#
# Species: 344
#   Regions without complements: ['1378513..1379481']
#   Complements only: []
#
# Species: 345
#   Regions without complements: ['1379481..1379798']
#   Complements only: []
#
# Species: 346
#   Regions without complements: ['1379816..1381639']
#   Complements only: []
#
# Species: 347
#   Regions without complements: ['1381657..1383123']
#   Complements only: []
#
# Species: 348
#   Regions without complements: ['141255..142334']
# ...
#   Complements only: ['235..402', '372..806', '816..2210', '2271..3896', '3899..4156', '4123..4479', '4492..4629', '4871..5608', '5605..6276', '6354..7100', '15294..16550', '16869..18935', '18950..19867', '21287..21535', '22028..23008', '23256..24788', '24792..26633', '26643..27602', '27593..27877', '27889..29535', '32644..33246', '33277..34263', '34311..35735', '36152..36430', '36527..36694', '38534..39190', '39103..40548', '40560..41936', '41998..43302', '43334..44281', '44299..44808', '48324..49457', '49461..49946', '52757..53311', '66324..68117', '68250..69233', '70975..71436', '75266..76153', '76210..76635', '79052..79963', '87681..89045', '89116..89985', '90013..90642', '93464..94318', '94319..94870', '94893..94991', '95592..97571', '97946..98779', '98786..99106', '99867..100634', '106649..107311', '111557..112753', '112750..113949', '113933..114715', '114761..115714', '115891..116037', '118690..119004', '126294..126890', '126887..128431', '128715..129542', '129657..130673', '132791..133261', '133431..133760', '134395..134475', '135888..136154', '136151..136750', '141066..142466', '143863..144972', '147278..148885', '150041..150499', '156407..157303', '159052..159303', '159419..162529', '162541..163647', '163666..164262', '166490..166897', '168232..168399', '175343..176941', '177450..177758', '183957..184388', '184360..186471', '186481..188169', '188166..189380', '189457..190821', '190915..191754', '197130..197798', '197873..198685', '198833..200599', '200761..201669', '204526..206361', '212440..213288', '216004..216492', '216558..217424', '219397..220374', '220385..221341', '221338..221928', '222087..223286', '228271..228765', '229975..230754', '230797..231870', '233672..234601', '234598..235341', '235338..236921', '236912..237292', '237289..238608', '238569..239357', '239354..240403', '240400..241440', '241437..242636', '242638..243204', '243212..244984', '245143..246087', '264254..265366', '265374..267239', '270697..271935', '271990..272562', '272562..273485', '277002..278060', '279539..280828', '280887..282479', '289352..291022', '291257..291934', '294219..294824', '294837..296213', '298752..299750', '299889..300185', '300209..301204', '301317..302204', '302413..303756', '303771..304232', '304289..304741', '305121..307070', '307273..307944', '307911..309734', '309689..309895', '314843..316336', '316344..317660', '329711..331051', '331146..331592', '333687..334814', '348820..349314', '353367..354515', '354684..356216', '356359..357300', '357398..358834', '359021..359878', '359871..361034', '363575..364684', '374240..374467', '374470..375453', '385659..386468', '389182..389601', '393036..393497', '393507..393974', '407506..408840', '412790..414145', '415806..417599', '417655..420477', '420633..421508', '421678..422322', '452940..454163', '456325..456708', '456859..457296', '457418..459982', '460153..461139', '461445..461915', '465207..466178', '470451..471260', '471271..471651', '471723..472571', '472552..473544', '473534..474829', '474882..477245', '479294..480919', '481683..482810', '482912..483184', '483198..484259', '486470..487645', '487639..488241', '488311..488742', '488788..489078', '489078..489635', '489689..490507', '490560..491270', '495796..496218', '496299..496862', '496898..497854', '497868..498599', '498737..499432', '499560..500048', '500170..501327', '503761..504657', '511704..512339', '514732..516144', '519298..520377', '520634..522394', '523156..525117', '525118..525654', '525623..526789', '527045..527920', '534198..534722', '536876..537103', '537151..537519', '537550..538284', '538423..538599', '538603..539046', '539097..539540', '539531..540004', '548780..550021', '550407..552284', '552383..554145', '554235..554678', '554708..554923', '557197..557823', '565832..568420', '568688..569575', '592295..593575', '593658..594461', '598403..599461', '599638..601008', '601137..601574', '608090..608659', '608662..609252', '609256..609624', '609611..611416', '614080..614748', '618683..619564', '619575..620369', ...
#
# Species: 2256
#   Regions without complements: ['37..1389', '1394..2494', '2667..3752', '3772..6186', '6402..7211', '7529..7696', '9923..11224', '11970..12383', '12664..13128', '13501..15159', '21718..22362', '24881..25795', '25805..27874', '28022..28252', '28347..29066', '29548..31479', '31616..32779', '32986..33540', '33619..33741', '33789..34145', '35145..35240', '40210..40797', '40846..43257', '43270..44241', '44238..44912', '44912..45841', '46025..47413', '47410..49383', '50142..50474', '51330..51533', '53310..53477', '53772..54764', '55655..56212', '56288..58786', '58879..59646', '59685..60671', '64130..65125', '65333..66865', '66852..68036', '68126..69319', '69706..70896', '71077..72345', '75549..75815', '75893..76648', '84883..86574', '86571..88103', '88470..89873', '90341..91804', '92315..94006', '94122..94712', '94709..96238', '96333..97664', '98170..99561', '99670..101433', '101493..101699', '102102..103709', '103992..105011', '105022..105924', '105938..106918', '106915..107991', '108109..109224', '109369..111555', '112196..112900', '113146..114864', '114989..115468', '115940..117229', '117594..119093', '120899..121744', '122049..124268', '126853..130065', '130167..131036', '131023..131526', '131595..132101', '138969..141011', '141015..141785', '146159..146494', '148262..149644', '152524..154047', '154040..155032', '155063..156007', '156082..156765', '156791..157651', '157661..158668', '159903..160115', '160244..160939', '161125..162063', '163688..164191', '164373..164606', '164797..164937', '164992..165381', '166518..167621', '167869..168345', '168356..168664', '168671..168958', '169116..169259', '170696..186709', '189137..191320', '191322..193310', '193320..194606', '194817..196247', '196560..199007', '201082..201456', '201765..202229', '202248..202664', '208774..211179', '211192..213288', '214896..215672', '215842..216111', '222609..223124', '223260..223979', '223976..225328', '232214..232408', '232521..233066', '255478..256041', '259062..259958', '259958..260563', '260511..261137', '261103..261531', '261722..263104', '263453..263974', '264031..265119', '265373..266362', '266446..267261', '267564..268241', '268234..268932', '268934..269974', '275768..277066', '278821..280866', '284007..284576', '284902..286443', '286686..287261', '287394..288611', '288750..288854', '292011..292418', '292696..292833', '292863..293342', '293418..294290', '294250..294681', '297192..297794', '297997..299058', '299067..299834', '299831..300685', '300682..301530', '305949..306497', '306501..308309', '308325..308546', '308641..309222', '309956..310756', '311010..311732', '311732..312127', '312127..312492', '312512..312799', '312937..313311', '313408..313878', '313972..316080', '316152..317336', '317539..317997', '318185..318379', '318458..318931', '319345..319656', '319689..320318', '320335..320940', '320937..321239', '321256..322080', '322095..322373', '322388..322720', '322738..323436', '323449..323859', '323859..324050', '324050..324304', '324485..324856', '324867..325181', '325196..325735', '325749..326054', '326088..326480', '326495..327028', '327038..327391', '327406..327909', '327912..328091', '328095..328529', '328537..329868', '329902..330018', '330166..330522', '330539..330928', '330959..331579', '331605..332594', '332635..333024', '333471..333896', '333984..334184', '339280..340401', '340373..340846', '340887..341426', '341428..342000', '342009..342830', '343731..343850', '349642..350679', '350676..351635', '354371..355555', '355806..356189', '356191..356736', '356927..357355', '357359..358063', '358428..358925', '358992..359360', '359703..363731', '363860..368080', '375013..375795', '375888..376673', '376792..377859', '377889..378629', '378675..379265', '379454..379729', '379779..380432', '383945..384064', '390322..391251', '391672..393270', '393317..394624', '394769..396607', '397784..401479', '407050..408696', '408831..409238', '413738..414100', '414088..415197', '415268..416539', '416780..417691', '418030..418440', '418431..418649', '419 ...
#   Complements only: ['7806..8759', '8753..9715', '11264..11602', '15272..16642', '16993..17436', '17850..19913', '20183..21163', '22493..23152', '23510..23965', '23962..24534', '34308..34784', '35316..35600', '35838..37787', '38131..38754', '39189..40013', '50488..51036', '51024..51209', '51682..52911', '60770..62224', '62348..63667', '72381..73151', '73144..74259', '74300..75067', '76836..77594', '77591..78598', '78588..79547', '79557..80510', '81033..82277', '82279..83208', '83291..83839', '83832..84155', '117291..117407', '119257..120201', '120480..120680', '124273..125070', '125074..126174', '132347..133483', '133494..134762', '134940..136067', '136278..137630', '137798..138640', '141850..143184', '143432..144775', '145022..145468', '146641..148236', '149780..152335', '158743..159480', '159480..159749', '162155..163471', '165566..166159', '186934..188631', '199169..200683', '203394..204152', '204187..205023', '205041..205370', '205745..208456', '213473..214048', '214108..214809', '216249..216506', '216542..218857', '218949..219176', '219700..222075', '225667..227286', '227483..228364', '228527..228934', '228963..229643', '229787..231934', '233187..233942', '234074..234511', '234521..235747', '235750..236319', '236316..237377', '237377..237721', '237782..238432', '238422..239645', '239629..240948', '240950..243157', '243157..243291', '243312..243479', '243595..243792', '243785..244285', '244288..244575', '244572..244814', '244811..245398', '245376..245630', '245621..246259', '246351..246620', '246632..247069', '247066..247467', '247452..247925', '247918..248310', '248303..248512', '248512..249054', '249044..249286', '249283..249504', '249501..250001', '250001..250699', '250782..250973', '250975..251613', '251603..251803', '251810..252043', '252062..252952', '252995..255049', '255051..255296', '256387..258942', '270092..271513', '271576..272382', '272577..272903', '272900..275446', '275480..275593', '277151..278335', '280963..281949', '282178..283491', '288837..290957', '291043..291675', '294859..295728', '295877..296113', '296110..297090', '301543..302523', '302616..303641', '303776..305698', '309423..309641', '334294..334698', '334846..336222', '336278..337567', '337661..338608', '338633..339145', '342885..343427', '351670..352620', '352831..353382', '353606..353740', '359506..359643', '368387..369517', '369510..370325', '370327..370542', '370539..371336', '371326..372000', '371987..374032', '374135..374251', '374407..374916', '380599..381885', '381945..383534', '389982..390254', '396727..397569', '405295..406680', '408693..408809', '409381..410271', '410285..411862', '412049..413260', '418592..419110', '447924..448286', '453206..454105', '454102..455232', '456528..457031', '457037..457966', '458147..458848', '464439..464642', '466708..467916', '470036..471223', '471375..472295', '480085..480939', '482582..482698', '482688..483863', '484200..484412', '484672..484884', '485144..485356', '485890..486357', '492765..493061', '493086..494051', '494640..495521', '495597..497051', '497041..497283', '498765..500114', '500126..500590', '500748..501200', '501462..502082', '502082..503182', '503405..504382', '518371..521229', '521283..521456', '521443..521802', '521799..522200', '522213..522515', '522649..527118', '527175..530768', '530809..533310', '533546..534358', '534673..535584', '541776..542324', '545439..545849', '546202..547863', '547958..549373', '549784..550737', '550971..551447', '551746..552132', '552270..552737', '552746..553681', '554019..554291', '554288..555142', '555448..555930', '556049..556336', '556360..557793', '557855..558580', '558587..559132', '559116..559679', '559676..560239', '560789..561862', '561886..562860', '568477..569628', '569655..571028', '571299..571703', '574200..574397', '575892..576377', '576977..578395', '578405..582862', '589052..589627', '589638..590228', '590499..590852', '590951..592924', '594484..595188', '596474..597460', '597546..597941', '598245..598529', '598526..598921', '598924..5992 ...

# %%
# Function to parse region and extract start, end, and length
def parse_region(region):
    start, *intermediate, end = region.split('..')
    if not intermediate:
        end = int(end)
        start = int(start)
        length = end - start + 1
        return start, end, length
    else:
        first_end, second_start = intermediate[0].split(',')   
        length1 = int(first_end) - int(start) + 1
        length2 = int(end) - int(second_start) + 1
        return int(start), int(end), length1 + length2

# Apply the function to the DataFrame
df[['Region_Start', 'Region_End', 'Region_Length']] = df['Region_Clean'].apply(lambda x: pd.Series(parse_region(x)))
# Out:
# /var/folders/24/jbn800492ks0n353ktq87jp00000gn/T/ipykernel_73615/2961581479.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[['Region_Start', 'Region_End', 'Region_Length']] = df['Region_Clean'].apply(lambda x: pd.Series(parse_region(x)))
# /var/folders/24/jbn800492ks0n353ktq87jp00000gn/T/ipykernel_73615/2961581479.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[['Region_Start', 'Region_End', 'Region_Length']] = df['Region_Clean'].apply(lambda x: pd.Series(parse_region(x)))
# /var/folders/24/jbn800492ks0n353ktq87jp00000gn/T/ipykernel_73615/2961581479.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[['Region_Start', 'Region_End', 'Region_Length']] = df['Region_Clean'].apply(lambda x: pd.Series(parse_region(x)))

# %%
df
# Out:
#            No  Respiration  Oxidase  Catalase  Gram_St  Species  Chromosome  \
# 0       91338            2      0.0         0        2     2252          39
# 1       91339            2      0.0         0        2     2252          39
# 2       91340            2      0.0         0        2     2252          39
# 3       91341            2      0.0         0        2     2252          39
# 4       91342            2      0.0         0        2     2252          39
# ...       ...          ...      ...       ...      ...      ...         ...
# 105083  63547            0      1.0         1        1     2243          29
# 105084  63548            0      1.0         1        1     2243          29
# 105085  63549            0      1.0         1        1     2243          29
# 105086  63550            0      1.0         1        1     2243          29
# 105087  63551            0      1.0         1        1     2243          29
#
#                               Region New_locus_tag Old_locus_tag  ...  \
# 0                            1..1362   SPD_RS00005      SPD_0001  ...
# 1                         1521..2657   SPD_RS00010      SPD_0002  ...
# 2                         2722..2916   SPD_RS00015      SPD_0003  ...
# 3                         3000..4115   SPD_RS00020      SPD_0004  ...
# 4                         4186..4755   SPD_RS00025      SPD_0005  ...
# ...                              ...           ...           ...  ...
# 105083  complement(2151190..2152827)           NaN       NGO2178  ...
# 105084              2152852..2152986           NaN       NGO2179  ...
# 105085  complement(2153000..2153221)           NaN       NGO2180  ...
# 105086  complement(2153286..2153651)           NaN       NGO2181  ...
# 105087  complement(2153654..2153788)           NaN       NGO2182  ...
#
#        NGON_Vic_3 (GE) - Total counts NGON_Vic_3 (GE) - RPKM  \
# 0                                 NaN                    NaN
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                                 NaN                    NaN
# 4                                 NaN                    NaN
# ...                               ...                    ...
# 105083                         3696.0             351.569874
# 105084                           12.0              13.849722
# 105085                          275.0             193.007110
# 105086                          530.0             225.625599
# 105087                         1101.0            1270.712022
#
#        NGON_Vic_3 (GE) - TPM  NGON_Vic_3 (GE) - CPM Is_Complement  \
# 0                        NaN                    NaN         False
# 1                        NaN                    NaN         False
# 2                        NaN                    NaN         False
# 3                        NaN                    NaN         False
# 4                        NaN                    NaN         False
# ...                      ...                    ...           ...
# 105083            424.146435             954.527459          True
# 105084             16.708799               3.099115         False
# 105085            232.850661              71.021388          True
# 105086            272.202770             136.877585          True
# 105087           1533.032303             284.343813          True
#
#             Region_Clean Is_circular Region_Start Region_End  Region_Length
# 0                1..1362       False            1       1362           1362
# 1             1521..2657       False         1521       2657           1137
# 2             2722..2916       False         2722       2916            195
# 3             3000..4115       False         3000       4115           1116
# 4             4186..4755       False         4186       4755            570
# ...                  ...         ...          ...        ...            ...
# 105083  2151190..2152827       False      2151190    2152827           1638
# 105084  2152852..2152986       False      2152852    2152986            135
# 105085  2153000..2153221       False      2153000    2153221            222
# 105086  2153286..2153651       False      2153286    2153651            366
# 105087  2153654..2153788       False      2153654    2153788            135
#
# [105088 rows x 4669 columns]

# %%
def read_csv_file(file_path):
    try:
        return pd.read_csv(file_path, delimiter=';', encoding='utf-8', low_memory=False)
    except pd.errors.ParserError:
        print(f"Error parsing {file_path}")
        return pd.DataFrame()

def parse_fna_file(filepath):
    return list(SeqIO.parse(filepath, "fasta"))

def parse_gff_file(filepath):
    return pd.read_csv(filepath, sep="\t", comment='#', header=None,
                       names=["seqid", "source", "type", "start", "end", "score", "strand", "phase", "attributes"])

def extract_gc_content(sequence):
    seq_str = str(sequence.seq)
    gc_content = (seq_str.count('G') + seq_str.count('C')) / len(seq_str)
    return gc_content

def calculate_rpkm(counts, length_kb, total_reads_million):
    return counts / (length_kb * total_reads_million)

def calculate_tpm(df):
    df['RPK'] = df['counts'] / df['length_kb']
    sum_rpk = df['RPK'].sum()
    df['TPM'] = (df['RPK'] * 1e6) / sum_rpk
    return df

# %%
data_path = f"{os.getcwd()}/data/data_sequences/"
fna_files = [os.path.join(data_path, f) for f in os.listdir(data_path) if f.endswith('.fna')]
gff_files = [os.path.join(data_path, f) for f in os.listdir(data_path) if f.endswith('.gff')]

all_features = []

for fna_file in fna_files:
    sequences = parse_fna_file(fna_file)
    for seq in sequences:
        gc_content = extract_gc_content(seq)
        try:
            species, sequence_type = seq.description[len(seq.id)+1:].split(", ")
        except:
            species = "Achromobacter xylosoxidans strain SOLR10"
            if seq.description.endswith("chromosome"):
                sequence_type = "chromosome"
            else:
                sequence_type = "plasmoid"
                
        file_name = os.path.basename(fna_file)[:-4]
        region, region_id = file_name.split(".")
        chromosome, chromosome_id = seq.id.split(".")
        all_features.append({"Region":region, "Region_ID": region_id,
                             "Chromosome":chromosome, "Chromosome_ID": chromosome_id,
                             'Species': species, "Sequence_Type": sequence_type,
                             'gc_content': gc_content, 'length_kb': len(seq) / 1000})

features_df = pd.DataFrame(all_features)

# Assuming you have a corresponding GFF file for each FNA file
for gff_file in gff_files:
    gff_data = parse_gff_file(gff_file)
    # Here, you can integrate gff_data with features_df if needed
    # Example: Merging based on 'seq_id' or other relevant columns

# total_reads_million = features_df['gc_content'].sum() / 1e6  # Adjust this based on actual read counts
# features_df['RPKM'] = calculate_rpkm(features_df['gc_content'], features_df['length_kb'], total_reads_million)
# features_df = calculate_tpm(features_df)

# print(features_df.head())

# %%
# Function to split and parse the string
def parse_column_values(column_value):
    key_value_pairs = column_value.split(';')
    parsed_dict = {}
    for pair in key_value_pairs:
        print(pair)
        key, val = pair.split('=')
        parsed_dict[key] = val
    return parsed_dict

def split_complex_values(value):
    # Initialize the parts with None
    part1, part2, part3, part4 = None, None, None, None

    if value:
        # Split based on '-'
        if '-' in value:
            part1, remainder = value.split('-', 1)
        else:
            part1, remainder = None, value

        # Split based on ':'
        if remainder and ':' in remainder:
            part2, remainder = remainder.split(':', 1)
        else:
            part2, remainder = remainder, ""

        # Split based on '..'
        if remainder:
            part4, part5 = remainder.split('..', 1)
        else:
            part4, part5 = None, None
        
        # Split based on '.'
        if part2 and '.' in part2:
            part2, part3 = part2.split('.', 1)
        else:
            part2, part3 = part2, None

    return part1, part2, part3, part4, part5


# Applying the function to the DataFrame column
parsed_data = gff_data['attributes'].apply(parse_column_values)

# Creating a new DataFrame with expanded columns
expanded_df = pd.DataFrame(parsed_data.tolist())

# Applying the complex value split to the 'ID' column
expanded_df[['seq_type', 'Chromosome', 'Chromosome_ID', 'Region_Start', 'Region_End']] = expanded_df['ID'].apply(lambda x: pd.Series(split_complex_values(x)))

# Dropping the original 'ID' column after expansion
expanded_df.drop(columns=['ID'], inplace=True)

# Concatenating with the original DataFrame
gff_data = pd.concat([gff_data, expanded_df], axis=1)
# Out:
# ID=NC_008767.1:1..2194961
# Dbxref=taxon:272831
# Is_circular=true
# Name=ANONYMOUS
# country=USA
# gbkey=Src
# genome=chromosome
# mol_type=genomic DNA
# serotype=C
# strain=FAM18
# ID=gene-NMC_RS00010
# Name=lpxC
# gbkey=Gene
# gene=lpxC
# gene_biotype=protein_coding
# locus_tag=NMC_RS00010
# old_locus_tag=NMC0001
# ID=cds-WP_002220060.1
# Parent=gene-NMC_RS00010
# Dbxref=GenBank:WP_002220060.1
# Name=WP_002220060.1
# Ontology_term=GO:0009245,GO:0008759
# gbkey=CDS
# gene=lpxC
# go_function=UDP-3-O-[3-hydroxymyristoyl] N-acetylglucosamine deacetylase activity|0008759||IEA
# go_process=lipid A biosynthetic process|0009245||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002246555.1
# locus_tag=NMC_RS00010
# product=UDP-3-O-acyl-N-acetylglucosamine deacetylase
# protein_id=WP_002220060.1
# transl_table=11
# ID=gene-NMC_RS00015
# Name=NMC_RS00015
# end_range=3610,.
# gbkey=Gene
# gene_biotype=pseudogene
# locus_tag=NMC_RS00015
# old_locus_tag=NMC0002
# partial=true
# pseudo=true
# ID=cds-NMC_RS00015
# Parent=gene-NMC_RS00015
# Note=incomplete%3B partial in the middle of a contig%3B missing N-terminus
# end_range=3610,.
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002247143.1
# locus_tag=NMC_RS00015
# partial=true
# product=pilin
# pseudo=true
# transl_table=11
# ID=gene-NMC_RS14610
# Name=NMC_RS14610
# end_range=4040,.
# gbkey=Gene
# gene_biotype=pseudogene
# locus_tag=NMC_RS14610
# partial=true
# pseudo=true
# start_range=.,3831
# ID=cds-NMC_RS14610
# Parent=gene-NMC_RS14610
# Note=incomplete%3B partial in the middle of a contig%3B missing N-terminus and C-terminus
# Ontology_term=GO:0007155,GO:0009289
# end_range=4040,.
# gbkey=CDS
# go_component=pilus|0009289||IEA
# go_process=cell adhesion|0007155||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_014573675.1
# locus_tag=NMC_RS14610
# partial=true
# product=pilin
# pseudo=true
# start_range=.,3831
# transl_table=11
# ID=gene-NMC_RS00025
# Name=NMC_RS00025
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00025
# old_locus_tag=NMC0004
# ID=cds-WP_002218455.1
# Parent=gene-NMC_RS00025
# Dbxref=GenBank:WP_002218455.1
# Name=WP_002218455.1
# Ontology_term=GO:0003755
# gbkey=CDS
# go_function=peptidyl-prolyl cis-trans isomerase activity|0003755||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002215210.1
# locus_tag=NMC_RS00025
# product=FKBP-type peptidyl-prolyl cis-trans isomerase
# protein_id=WP_002218455.1
# transl_table=11
# ID=gene-NMC_RS00030
# Name=NMC_RS00030
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00030
# old_locus_tag=NMC0005
# ID=cds-WP_002218456.1
# Parent=gene-NMC_RS00030
# Dbxref=GenBank:WP_002218456.1
# Name=WP_002218456.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002218456.1
# locus_tag=NMC_RS00030
# product=DUF2061 domain-containing protein
# protein_id=WP_002218456.1
# transl_table=11
# ID=gene-NMC_RS00035
# Name=NMC_RS00035
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00035
# old_locus_tag=NMC0006
# ID=cds-WP_002218457.1
# Parent=gene-NMC_RS00035
# Dbxref=GenBank:WP_002218457.1
# Name=WP_002218457.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002228827.1
# locus_tag=NMC_RS00035
# product=D-2-hydroxyacid dehydrogenase
# protein_id=WP_002218457.1
# transl_table=11
# ID=gene-NMC_RS00040
# Name=metG
# gbkey=Gene
# gene=metG
# gene_biotype=protein_coding
# locus_tag=NMC_RS00040
# old_locus_tag=NMC0007
# ID=cds-WP_011798736.1
# Parent=gene-NMC_RS00040
# Dbxref=GenBank:WP_011798736.1
# Name=WP_011798736.1
# Ontology_term=GO:0006431,GO:0000166,GO:0004825,GO:0005524
# gbkey=CDS
# gene=metG
# go_function=nucleotide binding|0000166||IEA,methionine-tRNA ligase activity|0004825||IEA,ATP binding|0005524||IEA
# go_process=methionyl-tRNA aminoacylation|0006431||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_010981066.1
# locus_tag=NMC_RS00040
# product=methionine--tRNA ligase
# protein_id=WP_011798736.1
# transl_table=11
# ID=gene-NMC_RS00045
# Name=glmS
# gbkey=Gene
# gene=glmS
# gene_biotype=protein_coding
# locus_tag=NMC_RS00045
# old_locus_tag=NMC0008
# ID=cds-WP_002218459.1
# Parent=gene-NMC_RS00045
# Dbxref=GenBank:WP_002218459.1
# Name=WP_002218459.1
# Ontology_term=GO:0006040,GO:0009252,GO:0004360
# gbkey=CDS
# gene=glmS
# go_function=glutamine-fructose-6-phosphate transaminase (isomerizing) activity|0004360||IEA
# go_process=amino sugar metabolic process|0006040||IEA,peptidoglycan biosynthetic process|0009252||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_017201253.1
# locus_tag=NMC_RS00045
# product=glutamine--fructose-6-phosphate transaminase (isomerizing)
# protein_id=WP_002218459.1
# transl_table=11
# ID=gene-NMC_RS00055
# Name=NMC_RS00055
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00055
# old_locus_tag=NMC0009
# ID=cds-WP_002247907.1
# Parent=gene-NMC_RS00055
# Dbxref=GenBank:WP_002247907.1
# Name=WP_002247907.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002247907.1
# locus_tag=NMC_RS00055
# product=hypothetical protein
# protein_id=WP_002247907.1
# transl_table=11
# ID=gene-NMC_RS00060
# Name=NMC_RS00060
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00060
# old_locus_tag=NMC0010
# ID=cds-WP_002220077.1
# Parent=gene-NMC_RS00060
# Dbxref=GenBank:WP_002220077.1
# Name=WP_002220077.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002260835.1
# locus_tag=NMC_RS00060
# product=murein transglycosylase A
# protein_id=WP_002220077.1
# transl_table=11
# ID=gene-NMC_RS00065
# Name=efeU
# gbkey=Gene
# gene=efeU
# gene_biotype=protein_coding
# locus_tag=NMC_RS00065
# old_locus_tag=NMC0011
# ID=cds-WP_002220079.1
# Parent=gene-NMC_RS00065
# Dbxref=GenBank:WP_002220079.1
# Name=WP_002220079.1
# Ontology_term=GO:0034755,GO:0005381,GO:0033573
# gbkey=CDS
# gene=efeU
# go_component=high-affinity iron permease complex|0033573||IEA
# go_function=iron ion transmembrane transporter activity|0005381||IEA
# go_process=iron ion transmembrane transport|0034755||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_019271751.1
# locus_tag=NMC_RS00065
# product=iron uptake transporter permease EfeU
# protein_id=WP_002220079.1
# transl_table=11
# ID=gene-NMC_RS00070
# Name=efeO
# gbkey=Gene
# gene=efeO
# gene_biotype=protein_coding
# locus_tag=NMC_RS00070
# old_locus_tag=NMC0012
# ID=cds-WP_002220080.1
# Parent=gene-NMC_RS00070
# Dbxref=GenBank:WP_002220080.1
# Name=WP_002220080.1
# Ontology_term=GO:0006826
# gbkey=CDS
# gene=efeO
# go_process=iron ion transport|0006826||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002247121.1
# locus_tag=NMC_RS00070
# product=iron uptake system protein EfeO
# protein_id=WP_002220080.1
# transl_table=11
# ID=gene-NMC_RS00075
# Name=efeB
# gbkey=Gene
# gene=efeB
# gene_biotype=protein_coding
# locus_tag=NMC_RS00075
# old_locus_tag=NMC0013
# ID=cds-WP_002220081.1
# Parent=gene-NMC_RS00075
# Dbxref=GenBank:WP_002220081.1
# Name=WP_002220081.1
# Ontology_term=GO:0033212,GO:0004601,GO:0020037
# gbkey=CDS
# gene=efeB
# go_function=peroxidase activity|0004601||IEA,heme binding|0020037||IEA
# go_process=iron import into cell|0033212||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002233352.1
# locus_tag=NMC_RS00075
# product=iron uptake transporter deferrochelatase/peroxidase subunit
# protein_id=WP_002220081.1
# transl_table=11
# ID=gene-NMC_RS00080
# Name=NMC_RS00080
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00080
# old_locus_tag=NMC0014
# ID=cds-WP_002220083.1
# Parent=gene-NMC_RS00080
# Dbxref=GenBank:WP_002220083.1
# Name=WP_002220083.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002218469.1
# locus_tag=NMC_RS00080
# product=zinc ribbon domain-containing protein YjdM
# protein_id=WP_002220083.1
# transl_table=11
# ID=gene-NMC_RS00085
# Name=glmU
# gbkey=Gene
# gene=glmU
# gene_biotype=protein_coding
# locus_tag=NMC_RS00085
# old_locus_tag=NMC0015
# ID=cds-WP_002220084.1
# Parent=gene-NMC_RS00085
# Dbxref=GenBank:WP_002220084.1
# Name=WP_002220084.1
# Ontology_term=GO:0009103,GO:0009252,GO:0003977,GO:0019134,GO:0005737
# gbkey=CDS
# gene=glmU
# go_component=cytoplasm|0005737||IEA
# go_function=UDP-N-acetylglucosamine diphosphorylase activity|0003977||IEA,glucosamine-1-phosphate N-acetyltransferase activity|0019134||IEA
# go_process=lipopolysaccharide biosynthetic process|0009103||IEA,peptidoglycan biosynthetic process|0009252||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002225769.1
# locus_tag=NMC_RS00085
# product=bifunctional UDP-N-acetylglucosamine diphosphorylase/glucosamine-1-phosphate N-acetyltransferase GlmU
# protein_id=WP_002220084.1
# transl_table=11
# ID=gene-NMC_RS14615
# Name=NMC_RS14615
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS14615
# ID=cds-WP_002258416.1
# Parent=gene-NMC_RS14615
# Dbxref=GenBank:WP_002258416.1
# Name=WP_002258416.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002215237.1
# locus_tag=NMC_RS14615
# product=spore cortex protein
# protein_id=WP_002258416.1
# transl_table=11
# ID=gene-NMC_RS14620
# Name=NMC_RS14620
# gbkey=Gene
# gene_biotype=pseudogene
# locus_tag=NMC_RS14620
# old_locus_tag=NMC0016
# pseudo=true
# ID=cds-NMC_RS14620
# Parent=gene-NMC_RS14620
# Note=frameshifted
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002240924.1
# locus_tag=NMC_RS14620
# product=pyrimidine 5'-nucleotidase
# pseudo=true
# transl_table=11
# ID=gene-NMC_RS00100
# Name=NMC_RS00100
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00100
# old_locus_tag=NMC0017
# ID=cds-WP_002220087.1
# Parent=gene-NMC_RS00100
# Dbxref=GenBank:WP_002220087.1
# Name=WP_002220087.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002216162.1
# locus_tag=NMC_RS00100
# product=thiamine ABC transporter substrate-binding protein
# protein_id=WP_002220087.1
# transl_table=11
# ID=gene-NMC_RS00105
# Name=NMC_RS00105
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00105
# old_locus_tag=NMC0018
# ID=cds-WP_002215243.1
# Parent=gene-NMC_RS00105
# Dbxref=GenBank:WP_002215243.1
# Name=WP_002215243.1
# Ontology_term=GO:0008381
# gbkey=CDS
# go_function=mechanosensitive monoatomic ion channel activity|0008381||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002215243.1
# locus_tag=NMC_RS00105
# product=mechanosensitive ion channel family protein
# protein_id=WP_002215243.1
# transl_table=11
# ID=gene-NMC_RS00110
# Name=NMC_RS00110
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00110
# old_locus_tag=NMC0019
# ID=cds-WP_002215245.1
# Parent=gene-NMC_RS00110
# Dbxref=GenBank:WP_002215245.1
# Name=WP_002215245.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002257085.1
# locus_tag=NMC_RS00110
# product=CinA family protein
# protein_id=WP_002215245.1
# transl_table=11
# ID=gene-NMC_RS00115
# Name=msrAB
# gbkey=Gene
# gene=msrAB
# gene_biotype=protein_coding
# locus_tag=NMC_RS00115
# old_locus_tag=NMC0020
# ID=cds-WP_002216163.1
# Parent=gene-NMC_RS00115
# Dbxref=GenBank:WP_002216163.1
# Name=WP_002216163.1
# gbkey=CDS
# gene=msrAB
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_019271765.1
# locus_tag=NMC_RS00115
# product=bifunctional peptide-methionine (S)-S-oxide reductase MsrA/peptide-methionine (R)-S-oxide reductase MsrB
# protein_id=WP_002216163.1
# transl_table=11
# ID=gene-NMC_RS00120
# Name=ftsY
# gbkey=Gene
# gene=ftsY
# gene_biotype=protein_coding
# locus_tag=NMC_RS00120
# old_locus_tag=NMC0021
# ID=cds-WP_002224230.1
# Parent=gene-NMC_RS00120
# Dbxref=GenBank:WP_002224230.1
# Name=WP_002224230.1
# Ontology_term=GO:0009306,GO:0003924,GO:0005047
# gbkey=CDS
# gene=ftsY
# go_function=GTPase activity|0003924||IEA,signal recognition particle binding|0005047||IEA
# go_process=protein secretion|0009306||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002215249.1
# locus_tag=NMC_RS00120
# product=signal recognition particle-docking protein FtsY
# protein_id=WP_002224230.1
# transl_table=11
# ID=gene-NMC_RS00125
# Name=NMC_RS00125
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00125
# old_locus_tag=NMC0022
# ID=cds-WP_002212521.1
# Parent=gene-NMC_RS00125
# Dbxref=GenBank:WP_002212521.1
# Name=WP_002212521.1
# Ontology_term=GO:0006313,GO:0004803
# gbkey=CDS
# go_function=transposase activity|0004803||IEA
# go_process=DNA transposition|0006313||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_003694155.1
# locus_tag=NMC_RS00125
# product=IS110-like element ISNgo3 family transposase
# protein_id=WP_002212521.1
# transl_table=11
# ID=gene-NMC_RS00130
# Name=NMC_RS00130
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00130
# old_locus_tag=NMC0023
# ID=cds-WP_011798737.1
# Parent=gene-NMC_RS00130
# Dbxref=GenBank:WP_011798737.1
# Name=WP_011798737.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_011798737.1
# locus_tag=NMC_RS00130
# product=zonular occludens toxin domain-containing protein
# protein_id=WP_011798737.1
# transl_table=11
# ID=gene-NMC_RS00135
# Name=NMC_RS00135
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00135
# old_locus_tag=NMC0024
# ID=cds-WP_011798738.1
# Parent=gene-NMC_RS00135
# Dbxref=GenBank:WP_011798738.1
# Name=WP_011798738.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_019273233.1
# locus_tag=NMC_RS00135
# product=DUF2523 domain-containing protein
# protein_id=WP_011798738.1
# transl_table=11
# ID=gene-NMC_RS00140
# Name=NMC_RS00140
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00140
# old_locus_tag=NMC0025
# ID=cds-WP_011798769.1
# Parent=gene-NMC_RS00140
# Dbxref=GenBank:WP_011798769.1
# Name=WP_011798769.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_019273676.1
# locus_tag=NMC_RS00140
# product=IgG-binding virulence factor TspB family protein
# protein_id=WP_011798769.1
# transl_table=11
# ID=gene-NMC_RS11505
# Name=NMC_RS11505
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11505
# ID=cds-WP_011798768.1
# Parent=gene-NMC_RS11505
# Dbxref=GenBank:WP_011798768.1
# Name=WP_011798768.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002212527.1
# locus_tag=NMC_RS11505
# product=hypothetical protein
# protein_id=WP_011798768.1
# transl_table=11
# ID=gene-NMC_RS00145
# Name=NMC_RS00145
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00145
# old_locus_tag=NMC0027
# ID=cds-WP_002219942.1
# Parent=gene-NMC_RS00145
# Dbxref=GenBank:WP_002219942.1
# Name=WP_002219942.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002254861.1
# locus_tag=NMC_RS00145
# product=hypothetical protein
# protein_id=WP_002219942.1
# transl_table=11
# ID=gene-NMC_RS00150
# Name=NMC_RS00150
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00150
# old_locus_tag=NMC0028
# ID=cds-WP_002216898.1
# Parent=gene-NMC_RS00150
# Dbxref=GenBank:WP_002216898.1
# Name=WP_002216898.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_003694609.1
# locus_tag=NMC_RS00150
# product=hypothetical protein
# protein_id=WP_002216898.1
# transl_table=11
# ID=gene-NMC_RS00155
# Name=NMC_RS00155
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00155
# old_locus_tag=NMC0029
# ID=cds-WP_002212530.1
# Parent=gene-NMC_RS00155
# Dbxref=GenBank:WP_002212530.1
# Name=WP_002212530.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002248765.1
# locus_tag=NMC_RS00155
# product=hypothetical protein
# protein_id=WP_002212530.1
# transl_table=11
# ID=gene-NMC_RS00160
# Name=NMC_RS00160
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00160
# old_locus_tag=NMC0030
# ID=cds-WP_002212531.1
# Parent=gene-NMC_RS00160
# Dbxref=GenBank:WP_002212531.1
# Name=WP_002212531.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002212531.1
# locus_tag=NMC_RS00160
# product=hypothetical protein
# protein_id=WP_002212531.1
# transl_table=11
# ID=gene-NMC_RS00165
# Name=NMC_RS00165
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00165
# old_locus_tag=NMC0031
# ID=cds-WP_002212532.1
# Parent=gene-NMC_RS00165
# Dbxref=GenBank:WP_002212532.1
# Name=WP_002212532.1
# Ontology_term=GO:0006270,GO:0003677,GO:0003916
# gbkey=CDS
# go_function=DNA binding|0003677||IEA,DNA topoisomerase activity|0003916||IEA
# go_process=DNA replication initiation|0006270||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002239390.1
# locus_tag=NMC_RS00165
# product=replication initiation factor domain-containing protein
# protein_id=WP_002212532.1
# transl_table=11
# ID=gene-NMC_RS00175
# Name=pilC
# gbkey=Gene
# gene=pilC
# gene_biotype=protein_coding
# locus_tag=NMC_RS00175
# old_locus_tag=NMC0033
# ID=cds-WP_011798740.1
# Parent=gene-NMC_RS00175
# Dbxref=GenBank:WP_011798740.1
# Name=WP_011798740.1
# gbkey=CDS
# gene=pilC
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002247914.1
# locus_tag=NMC_RS00175
# product=PilC family type IV pilus tip adhesin
# protein_id=WP_011798740.1
# transl_table=11
# ID=gene-NMC_RS00180
# Name=yccS
# gbkey=Gene
# gene=yccS
# gene_biotype=protein_coding
# locus_tag=NMC_RS00180
# old_locus_tag=NMC0034
# ID=cds-WP_002220096.1
# Parent=gene-NMC_RS00180
# Dbxref=GenBank:WP_002220096.1
# Name=WP_002220096.1
# Ontology_term=GO:0016020
# gbkey=CDS
# gene=yccS
# go_component=membrane|0016020||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002240871.1
# locus_tag=NMC_RS00180
# product=YccS family putative transporter
# protein_id=WP_002220096.1
# transl_table=11
# ID=gene-NMC_RS00185
# Name=NMC_RS00185
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00185
# old_locus_tag=NMC0035
# ID=cds-WP_002218483.1
# Parent=gene-NMC_RS00185
# Dbxref=GenBank:WP_002218483.1
# Name=WP_002218483.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002215256.1
# locus_tag=NMC_RS00185
# product=PilT/PilU family type 4a pilus ATPase
# protein_id=WP_002218483.1
# transl_table=11
# ID=gene-NMC_RS00190
# Name=pilT
# gbkey=Gene
# gene=pilT
# gene_biotype=protein_coding
# locus_tag=NMC_RS00190
# old_locus_tag=NMC0036
# ID=cds-WP_011798741.1
# Parent=gene-NMC_RS00190
# Dbxref=GenBank:WP_011798741.1
# Name=WP_011798741.1
# gbkey=CDS
# gene=pilT
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_003690200.1
# locus_tag=NMC_RS00190
# product=type IV pilus twitching motility protein PilT
# protein_id=WP_011798741.1
# transl_table=11
# ID=gene-NMC_RS00195
# Name=NMC_RS00195
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00195
# old_locus_tag=NMC0037
# ID=cds-WP_002242149.1
# Parent=gene-NMC_RS00195
# Dbxref=GenBank:WP_002242149.1
# Name=WP_002242149.1
# Ontology_term=GO:0030170
# gbkey=CDS
# go_function=pyridoxal phosphate binding|0030170||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002220097.1
# locus_tag=NMC_RS00195
# product=YggS family pyridoxal phosphate-dependent enzyme
# protein_id=WP_002242149.1
# transl_table=11
# ID=gene-NMC_RS00200
# Name=NMC_RS00200
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00200
# old_locus_tag=NMC0038
# ID=cds-WP_002242150.1
# Parent=gene-NMC_RS00200
# Dbxref=GenBank:WP_002242150.1
# Name=WP_002242150.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_015815987.1
# locus_tag=NMC_RS00200
# product=hypothetical protein
# protein_id=WP_002242150.1
# transl_table=11
# ID=gene-NMC_RS00205
# Name=proC
# gbkey=Gene
# gene=proC
# gene_biotype=protein_coding
# locus_tag=NMC_RS00205
# old_locus_tag=NMC0039
# ID=cds-WP_002215263.1
# Parent=gene-NMC_RS00205
# Dbxref=GenBank:WP_002215263.1
# Name=WP_002215263.1
# Ontology_term=GO:0006561,GO:0004735
# gbkey=CDS
# gene=proC
# go_function=pyrroline-5-carboxylate reductase activity|0004735||IEA
# go_process=proline biosynthetic process|0006561||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002243165.1
# locus_tag=NMC_RS00205
# product=pyrroline-5-carboxylate reductase
# protein_id=WP_002215263.1
# transl_table=11
# ID=gene-NMC_RS00210
# Name=dksA
# gbkey=Gene
# gene=dksA
# gene_biotype=protein_coding
# locus_tag=NMC_RS00210
# old_locus_tag=NMC0040
# ID=cds-WP_002215267.1
# Parent=gene-NMC_RS00210
# Dbxref=GenBank:WP_002215267.1
# Name=WP_002215267.1
# Ontology_term=GO:0006355,GO:0019899
# gbkey=CDS
# gene=dksA
# go_function=enzyme binding|0019899||IEA
# go_process=regulation of DNA-templated transcription|0006355||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002224742.1
# locus_tag=NMC_RS00210
# product=RNA polymerase-binding protein DksA
# protein_id=WP_002215267.1
# transl_table=11
# ID=gene-NMC_RS00220
# Name=NMC_RS00220
# gbkey=Gene
# gene_biotype=rRNA
# locus_tag=NMC_RS00220
# old_locus_tag=NMC_r01
# ID=rna-NMC_RS00220
# Parent=gene-NMC_RS00220
# Dbxref=RFAM:RF00177
# gbkey=rRNA
# inference=COORDINATES: profile:INFERNAL:1.1.5
# locus_tag=NMC_RS00220
# product=16S ribosomal RNA
# ID=exon-NMC_RS00220-1
# Parent=rna-NMC_RS00220
# Dbxref=RFAM:RF00177
# gbkey=rRNA
# inference=COORDINATES: profile:INFERNAL:1.1.5
# locus_tag=NMC_RS00220
# product=16S ribosomal RNA
# ID=gene-NMC_RS00225
# Name=NMC_RS00225
# gbkey=Gene
# gene_biotype=tRNA
# locus_tag=NMC_RS00225
# old_locus_tag=NMC_t01
# ID=rna-NMC_RS00225
# Parent=gene-NMC_RS00225
# anticodon=(pos:48314..48316)
# gbkey=tRNA
# inference=COORDINATES: profile:tRNAscan-SE:2.0.12
# locus_tag=NMC_RS00225
# product=tRNA-Ile
# ID=exon-NMC_RS00225-1
# Parent=rna-NMC_RS00225
# anticodon=(pos:48314..48316)
# gbkey=tRNA
# inference=COORDINATES: profile:tRNAscan-SE:2.0.12
# locus_tag=NMC_RS00225
# product=tRNA-Ile
# ID=gene-NMC_RS00230
# Name=NMC_RS00230
# gbkey=Gene
# gene_biotype=tRNA
# locus_tag=NMC_RS00230
# old_locus_tag=NMC_t02
# ID=rna-NMC_RS00230
# Parent=gene-NMC_RS00230
# anticodon=(pos:48395..48397)
# gbkey=tRNA
# inference=COORDINATES: profile:tRNAscan-SE:2.0.12
# locus_tag=NMC_RS00230
# product=tRNA-Ala
# ID=exon-NMC_RS00230-1
# Parent=rna-NMC_RS00230
# anticodon=(pos:48395..48397)
# gbkey=tRNA
# inference=COORDINATES: profile:tRNAscan-SE:2.0.12
# locus_tag=NMC_RS00230
# product=tRNA-Ala
# ID=gene-NMC_RS00235
# Name=NMC_RS00235
# gbkey=Gene
# gene_biotype=rRNA
# locus_tag=NMC_RS00235
# old_locus_tag=NMC_r02
# ID=rna-NMC_RS00235
# Parent=gene-NMC_RS00235
# Dbxref=RFAM:RF02541
# gbkey=rRNA
# inference=COORDINATES: profile:INFERNAL:1.1.5
# locus_tag=NMC_RS00235
# product=23S ribosomal RNA
# ID=exon-NMC_RS00235-1
# Parent=rna-NMC_RS00235
# Dbxref=RFAM:RF02541
# gbkey=rRNA
# inference=COORDINATES: profile:INFERNAL:1.1.5
# locus_tag=NMC_RS00235
# product=23S ribosomal RNA
# ID=gene-NMC_RS00240
# Name=rrf
# gbkey=Gene
# gene=rrf
# gene_biotype=rRNA
# locus_tag=NMC_RS00240
# old_locus_tag=NMC_r03
# ID=rna-NMC_RS00240
# Parent=gene-NMC_RS00240
# Dbxref=RFAM:RF00001
# gbkey=rRNA
# gene=rrf
# inference=COORDINATES: profile:INFERNAL:1.1.5
# locus_tag=NMC_RS00240
# product=5S ribosomal RNA
# ID=exon-NMC_RS00240-1
# Parent=rna-NMC_RS00240
# Dbxref=RFAM:RF00001
# gbkey=rRNA
# gene=rrf
# inference=COORDINATES: profile:INFERNAL:1.1.5
# locus_tag=NMC_RS00240
# product=5S ribosomal RNA
# ID=gene-NMC_RS00245
# Name=NMC_RS00245
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00245
# old_locus_tag=NMC0041
# ID=cds-WP_011798742.1
# Parent=gene-NMC_RS00245
# Dbxref=GenBank:WP_011798742.1
# Name=WP_011798742.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_011798959.1
# locus_tag=NMC_RS00245
# product=ComEA family DNA-binding protein
# protein_id=WP_011798742.1
# transl_table=11
# ID=gene-NMC_RS00255
# Name=dnaJ
# gbkey=Gene
# gene=dnaJ
# gene_biotype=protein_coding
# locus_tag=NMC_RS00255
# old_locus_tag=NMC0043
# ID=cds-WP_002215274.1
# Parent=gene-NMC_RS00255
# Dbxref=GenBank:WP_002215274.1
# Name=WP_002215274.1
# Ontology_term=GO:0006457,GO:0009408,GO:0005515
# gbkey=CDS
# gene=dnaJ
# go_function=protein binding|0005515||IEA
# go_process=protein folding|0006457||IEA,response to heat|0009408||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_003703320.1
# locus_tag=NMC_RS00255
# product=molecular chaperone DnaJ
# protein_id=WP_002215274.1
# transl_table=11
# ID=gene-NMC_RS00260
# Name=NMC_RS00260
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00260
# old_locus_tag=NMC0044
# ID=cds-WP_002224367.1
# Parent=gene-NMC_RS00260
# Dbxref=GenBank:WP_002224367.1
# Name=WP_002224367.1
# Ontology_term=GO:0006857,GO:0035673,GO:0016020
# gbkey=CDS
# go_component=membrane|0016020||IEA
# go_function=oligopeptide transmembrane transporter activity|0035673||IEA
# go_process=oligopeptide transport|0006857||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_010951366.1
# locus_tag=NMC_RS00260
# product=oligopeptide transporter%2C OPT family
# protein_id=WP_002224367.1
# transl_table=11
# ID=gene-NMC_RS00265
# Name=rfbC
# gbkey=Gene
# gene=rfbC
# gene_biotype=protein_coding
# locus_tag=NMC_RS00265
# old_locus_tag=NMC0045
# ID=cds-WP_002224368.1
# Parent=gene-NMC_RS00265
# Dbxref=GenBank:WP_002224368.1
# Name=WP_002224368.1
# Ontology_term=GO:0009243,GO:0019305,GO:0008830
# gbkey=CDS
# gene=rfbC
# go_function=dTDP-4-dehydrorhamnose 3%2C5-epimerase activity|0008830||IEA
# go_process=O antigen biosynthetic process|0009243||IEA,dTDP-rhamnose biosynthetic process|0019305||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002224368.1
# locus_tag=NMC_RS00265
# product=dTDP-4-dehydrorhamnose 3%2C5-epimerase
# protein_id=WP_002224368.1
# transl_table=11
# ID=gene-NMC_RS00270
# Name=rfbA
# gbkey=Gene
# gene=rfbA
# gene_biotype=protein_coding
# locus_tag=NMC_RS00270
# old_locus_tag=NMC0046
# ID=cds-WP_002224369.1
# Parent=gene-NMC_RS00270
# Dbxref=GenBank:WP_002224369.1
# Name=WP_002224369.1
# Ontology_term=GO:0009243,GO:0019305,GO:0008879
# gbkey=CDS
# gene=rfbA
# go_function=glucose-1-phosphate thymidylyltransferase activity|0008879||IEA
# go_process=O antigen biosynthetic process|0009243||IEA,dTDP-rhamnose biosynthetic process|0019305||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002221803.1
# locus_tag=NMC_RS00270
# product=glucose-1-phosphate thymidylyltransferase RfbA
# protein_id=WP_002224369.1
# transl_table=11
# ID=gene-NMC_RS00275
# Name=rfbB
# gbkey=Gene
# gene=rfbB
# gene_biotype=protein_coding
# locus_tag=NMC_RS00275
# old_locus_tag=NMC0047
# ID=cds-WP_002231450.1
# Parent=gene-NMC_RS00275
# Dbxref=GenBank:WP_002231450.1
# Name=WP_002231450.1
# Ontology_term=GO:0009243,GO:0019305,GO:0008460
# gbkey=CDS
# gene=rfbB
# go_function=dTDP-glucose 4%2C6-dehydratase activity|0008460||IEA
# go_process=O antigen biosynthetic process|0009243||IEA,dTDP-rhamnose biosynthetic process|0019305||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_009174852.1
# locus_tag=NMC_RS00275
# product=dTDP-glucose 4%2C6-dehydratase
# protein_id=WP_002231450.1
# transl_table=11
# ID=gene-NMC_RS00280
# Name=galE
# gbkey=Gene
# gene=galE
# gene_biotype=protein_coding
# locus_tag=NMC_RS00280
# old_locus_tag=NMC0048
# ID=cds-WP_002247920.1
# Parent=gene-NMC_RS00280
# Dbxref=GenBank:WP_002247920.1
# Name=WP_002247920.1
# Ontology_term=GO:0006012,GO:0003978
# gbkey=CDS
# gene=galE
# go_function=UDP-glucose 4-epimerase activity|0003978||IEA
# go_process=galactose metabolic process|0006012||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002248656.1
# locus_tag=NMC_RS00280
# product=UDP-glucose 4-epimerase GalE
# protein_id=WP_002247920.1
# transl_table=11
# ID=gene-NMC_RS00285
# Name=NMC_RS00285
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00285
# old_locus_tag=NMC0049
# ID=cds-WP_311554829.1
# Parent=gene-NMC_RS00285
# Dbxref=GenBank:WP_311554829.1
# Name=WP_311554829.1
# gbkey=CDS
# inference=COORDINATES: protein motif:HMM:NF042780.2
# locus_tag=NMC_RS00285
# product=DUF6716 putative glycosyltransferase
# protein_id=WP_311554829.1
# transl_table=11
# ID=gene-NMC_RS00290
# Name=oatC
# gbkey=Gene
# gene=oatC
# gene_biotype=protein_coding
# locus_tag=NMC_RS00290
# old_locus_tag=NMC0050
# ID=cds-WP_002247492.1
# Parent=gene-NMC_RS00290
# Dbxref=GenBank:WP_002247492.1
# Name=WP_002247492.1
# gbkey=CDS
# gene=oatC
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002247492.1
# locus_tag=NMC_RS00290
# product=capsular polysaccharide O-acetyltransferase OatC
# protein_id=WP_002247492.1
# transl_table=11
# ID=gene-NMC_RS00295
# Name=NMC_RS00295
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00295
# old_locus_tag=NMC0051
# ID=cds-WP_002247491.1
# Parent=gene-NMC_RS00295
# Dbxref=GenBank:WP_002247491.1
# Name=WP_002247491.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002247723.1
# locus_tag=NMC_RS00295
# product=alpha-2%2C8-polysialyltransferase family protein
# protein_id=WP_002247491.1
# transl_table=11
# ID=gene-NMC_RS00300
# Name=siaC
# gbkey=Gene
# gene=siaC
# gene_biotype=protein_coding
# locus_tag=NMC_RS00300
# old_locus_tag=NMC0052
# ID=cds-WP_002215299.1
# Parent=gene-NMC_RS00300
# Dbxref=GenBank:WP_002215299.1
# Name=WP_002215299.1
# gbkey=CDS
# gene=siaC
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002215299.1
# locus_tag=NMC_RS00300
# product=polysialic acid capsule biosynthesis protein SiaC
# protein_id=WP_002215299.1
# transl_table=11
# ID=gene-NMC_RS00305
# Name=neuA
# gbkey=Gene
# gene=neuA
# gene_biotype=protein_coding
# locus_tag=NMC_RS00305
# old_locus_tag=NMC0053
# ID=cds-WP_002215295.1
# Parent=gene-NMC_RS00305
# Dbxref=GenBank:WP_002215295.1
# Name=WP_002215295.1
# gbkey=CDS
# gene=neuA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002215295.1
# locus_tag=NMC_RS00305
# product=N-acylneuraminate cytidylyltransferase
# protein_id=WP_002215295.1
# transl_table=11
# ID=gene-NMC_RS00310
# Name=neuC
# gbkey=Gene
# gene=neuC
# gene_biotype=protein_coding
# locus_tag=NMC_RS00310
# old_locus_tag=NMC0054
# ID=cds-WP_002226892.1
# Parent=gene-NMC_RS00310
# Dbxref=GenBank:WP_002226892.1
# Name=WP_002226892.1
# Ontology_term=GO:0006047,GO:0008761
# gbkey=CDS
# gene=neuC
# go_function=UDP-N-acetylglucosamine 2-epimerase activity|0008761||IEA
# go_process=UDP-N-acetylglucosamine metabolic process|0006047||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002257094.1
# locus_tag=NMC_RS00310
# product=UDP-N-acetylglucosamine 2-epimerase
# protein_id=WP_002226892.1
# transl_table=11
# ID=gene-NMC_RS00315
# Name=ctrA
# gbkey=Gene
# gene=ctrA
# gene_biotype=protein_coding
# locus_tag=NMC_RS00315
# old_locus_tag=NMC0055
# ID=cds-WP_002215290.1
# Parent=gene-NMC_RS00315
# Dbxref=GenBank:WP_002215290.1
# Name=WP_002215290.1
# gbkey=CDS
# gene=ctrA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002215290.1
# locus_tag=NMC_RS00315
# product=capsule polysaccharide export outer membrane protein CtrA
# protein_id=WP_002215290.1
# transl_table=11
# ID=gene-NMC_RS00320
# Name=ctrB
# gbkey=Gene
# gene=ctrB
# gene_biotype=protein_coding
# locus_tag=NMC_RS00320
# old_locus_tag=NMC0056
# ID=cds-WP_002215287.1
# Parent=gene-NMC_RS00320
# Dbxref=GenBank:WP_002215287.1
# Name=WP_002215287.1
# gbkey=CDS
# gene=ctrB
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002215287.1
# locus_tag=NMC_RS00320
# product=capsule polysaccharide export protein CtrB
# protein_id=WP_002215287.1
# transl_table=11
# ID=gene-NMC_RS00325
# Name=NMC_RS00325
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00325
# old_locus_tag=NMC0057
# ID=cds-WP_002224374.1
# Parent=gene-NMC_RS00325
# Dbxref=GenBank:WP_002224374.1
# Name=WP_002224374.1
# Ontology_term=GO:0140359,GO:0043190
# gbkey=CDS
# go_component=ATP-binding cassette (ABC) transporter complex|0043190||IEA
# go_function=ABC-type transporter activity|0140359||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_004519071.1
# locus_tag=NMC_RS00325
# product=ABC transporter permease
# protein_id=WP_002224374.1
# transl_table=11
# ID=gene-NMC_RS00330
# Name=NMC_RS00330
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00330
# old_locus_tag=NMC0058
# ID=cds-WP_002218516.1
# Parent=gene-NMC_RS00330
# Dbxref=GenBank:WP_002218516.1
# Name=WP_002218516.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002220117.1
# locus_tag=NMC_RS00330
# product=ABC transporter ATP-binding protein
# protein_id=WP_002218516.1
# transl_table=11
# ID=gene-NMC_RS00335
# Name=NMC_RS00335
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00335
# old_locus_tag=NMC0059
# ID=cds-WP_002226891.1
# Parent=gene-NMC_RS00335
# Dbxref=GenBank:WP_002226891.1
# Name=WP_002226891.1
# Ontology_term=GO:0003676,GO:0003729,GO:0005829
# gbkey=CDS
# go_component=cytosol|0005829||IEA
# go_function=nucleic acid binding|0003676||IEA,mRNA binding|0003729||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002225921.1
# locus_tag=NMC_RS00335
# product=Tex family protein
# protein_id=WP_002226891.1
# transl_table=11
# ID=gene-NMC_RS00340
# Name=dcm
# gbkey=Gene
# gene=dcm
# gene_biotype=protein_coding
# locus_tag=NMC_RS00340
# old_locus_tag=NMC0060
# ID=cds-WP_002215283.1
# Parent=gene-NMC_RS00340
# Dbxref=GenBank:WP_002215283.1
# Name=WP_002215283.1
# Ontology_term=GO:0006304,GO:0003886
# gbkey=CDS
# gene=dcm
# go_function=DNA (cytosine-5-)-methyltransferase activity|0003886||IEA
# go_process=DNA modification|0006304||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002215283.1
# locus_tag=NMC_RS00340
# product=DNA (cytosine-5-)-methyltransferase
# protein_id=WP_002215283.1
# transl_table=11
# ID=gene-NMC_RS14855
# Name=NMC_RS14855
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS14855
# ID=cds-WP_002215282.1
# Parent=gene-NMC_RS14855
# Dbxref=GenBank:WP_002215282.1
# Name=WP_002215282.1
# Ontology_term=GO:0008168
# gbkey=CDS
# go_function=methyltransferase activity|0008168||IEA
# inference=COORDINATES: protein motif:HMM:NF012372.4
# locus_tag=NMC_RS14855
# product=DNA cytosine methyltransferase
# protein_id=WP_002215282.1
# transl_table=11
# ID=gene-NMC_RS00350
# Name=NMC_RS00350
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00350
# old_locus_tag=NMC0061
# ID=cds-WP_002231447.1
# Parent=gene-NMC_RS00350
# Dbxref=GenBank:WP_002231447.1
# Name=WP_002231447.1
# Ontology_term=GO:0032775,GO:0009007
# gbkey=CDS
# go_function=site-specific DNA-methyltransferase (adenine-specific) activity|0009007||IEA
# go_process=DNA methylation on adenine|0032775||IEA
# inference=COORDINATES: protein motif:HMM:NF014177.4
# locus_tag=NMC_RS00350
# product=DNA adenine methylase
# protein_id=WP_002231447.1
# transl_table=11
# ID=gene-NMC_RS00355
# Name=galE
# gbkey=Gene
# gene=galE
# gene_biotype=pseudogene
# locus_tag=NMC_RS00355
# old_locus_tag=NMC0062
# partial=true
# pseudo=true
# start_range=.,74785
# ID=cds-NMC_RS00355
# Parent=gene-NMC_RS00355
# Note=incomplete%3B partial in the middle of a contig%3B missing N-terminus
# Ontology_term=GO:0006012,GO:0003978
# gbkey=CDS
# gene=galE
# go_function=UDP-glucose 4-epimerase activity|0003978||IEA
# go_process=galactose metabolic process|0006012||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002248656.1
# locus_tag=NMC_RS00355
# partial=true
# product=UDP-glucose 4-epimerase GalE
# pseudo=true
# start_range=.,74785
# transl_table=11
# ID=gene-NMC_RS00360
# Name=rfbB
# gbkey=Gene
# gene=rfbB
# gene_biotype=protein_coding
# locus_tag=NMC_RS00360
# old_locus_tag=NMC0063
# ID=cds-WP_002231450.1-2
# Parent=gene-NMC_RS00360
# Dbxref=GenBank:WP_002231450.1
# Name=WP_002231450.1
# Ontology_term=GO:0009243,GO:0019305,GO:0008460
# gbkey=CDS
# gene=rfbB
# go_function=dTDP-glucose 4%2C6-dehydratase activity|0008460||IEA
# go_process=O antigen biosynthetic process|0009243||IEA,dTDP-rhamnose biosynthetic process|0019305||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_009174852.1
# locus_tag=NMC_RS00360
# product=dTDP-glucose 4%2C6-dehydratase
# protein_id=WP_002231450.1
# transl_table=11
# ID=gene-NMC_RS00365
# Name=rfbA
# gbkey=Gene
# gene=rfbA
# gene_biotype=protein_coding
# locus_tag=NMC_RS00365
# old_locus_tag=NMC0064
# ID=cds-WP_002224369.1-2
# Parent=gene-NMC_RS00365
# Dbxref=GenBank:WP_002224369.1
# Name=WP_002224369.1
# Ontology_term=GO:0009243,GO:0019305,GO:0008879
# gbkey=CDS
# gene=rfbA
# go_function=glucose-1-phosphate thymidylyltransferase activity|0008879||IEA
# go_process=O antigen biosynthetic process|0009243||IEA,dTDP-rhamnose biosynthetic process|0019305||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002221803.1
# locus_tag=NMC_RS00365
# product=glucose-1-phosphate thymidylyltransferase RfbA
# protein_id=WP_002224369.1
# transl_table=11
# ID=gene-NMC_RS00370
# Name=rfbC
# gbkey=Gene
# gene=rfbC
# gene_biotype=protein_coding
# locus_tag=NMC_RS00370
# old_locus_tag=NMC0065
# ID=cds-WP_002247921.1
# Parent=gene-NMC_RS00370
# Dbxref=GenBank:WP_002247921.1
# Name=WP_002247921.1
# Ontology_term=GO:0009243,GO:0019305,GO:0008830
# gbkey=CDS
# gene=rfbC
# go_function=dTDP-4-dehydrorhamnose 3%2C5-epimerase activity|0008830||IEA
# go_process=O antigen biosynthetic process|0009243||IEA,dTDP-rhamnose biosynthetic process|0019305||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002259384.1
# locus_tag=NMC_RS00370
# product=dTDP-4-dehydrorhamnose 3%2C5-epimerase
# protein_id=WP_002247921.1
# transl_table=11
# ID=gene-NMC_RS00375
# Name=NMC_RS00375
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00375
# old_locus_tag=NMC0066
# ID=cds-WP_002247922.1
# Parent=gene-NMC_RS00375
# Dbxref=GenBank:WP_002247922.1
# Name=WP_002247922.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002243182.1
# locus_tag=NMC_RS00375
# product=capsular polysaccharide biosynthesis protein
# protein_id=WP_002247922.1
# transl_table=11
# ID=gene-NMC_RS00380
# Name=NMC_RS00380
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00380
# old_locus_tag=NMC0067
# ID=cds-WP_002247923.1
# Parent=gene-NMC_RS00380
# Dbxref=GenBank:WP_002247923.1
# Name=WP_002247923.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002237518.1
# locus_tag=NMC_RS00380
# product=capsule biosynthesis protein
# protein_id=WP_002247923.1
# transl_table=11
# ID=gene-NMC_RS00385
# Name=NMC_RS00385
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00385
# old_locus_tag=NMC0068
# ID=cds-WP_002226901.1
# Parent=gene-NMC_RS00385
# Dbxref=GenBank:WP_002226901.1
# Name=WP_002226901.1
# Ontology_term=GO:0005515
# gbkey=CDS
# go_function=protein binding|0005515||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002220127.1
# locus_tag=NMC_RS00385
# product=tetratricopeptide repeat protein
# protein_id=WP_002226901.1
# transl_table=11
# ID=gene-NMC_RS00390
# Name=gltS
# gbkey=Gene
# gene=gltS
# gene_biotype=protein_coding
# locus_tag=NMC_RS00390
# old_locus_tag=NMC0069
# ID=cds-WP_002224378.1
# Parent=gene-NMC_RS00390
# Dbxref=GenBank:WP_002224378.1
# Name=WP_002224378.1
# Ontology_term=GO:0015813,GO:0015501
# gbkey=CDS
# gene=gltS
# go_function=glutamate:sodium symporter activity|0015501||IEA
# go_process=L-glutamate transmembrane transport|0015813||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_003754352.1
# locus_tag=NMC_RS00390
# product=sodium/glutamate symporter
# protein_id=WP_002224378.1
# transl_table=11
# ID=gene-NMC_RS00395
# Name=NMC_RS00395
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00395
# old_locus_tag=NMC0071
# ID=cds-WP_002216199.1
# Parent=gene-NMC_RS00395
# Dbxref=GenBank:WP_002216199.1
# Name=WP_002216199.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002235351.1
# locus_tag=NMC_RS00395
# product=lysozyme inhibitor LprI family protein
# protein_id=WP_002216199.1
# transl_table=11
# ID=gene-NMC_RS00400
# Name=NMC_RS00400
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00400
# old_locus_tag=NMC0072
# ID=cds-WP_002215316.1
# Parent=gene-NMC_RS00400
# Dbxref=GenBank:WP_002215316.1
# Name=WP_002215316.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002215316.1
# locus_tag=NMC_RS00400
# product=hypothetical protein
# protein_id=WP_002215316.1
# transl_table=11
# ID=gene-NMC_RS14310
# Name=NMC_RS14310
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS14310
# ID=cds-WP_019742709.1
# Parent=gene-NMC_RS14310
# Dbxref=GenBank:WP_019742709.1
# Name=WP_019742709.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_017629096.1
# locus_tag=NMC_RS14310
# product=hypothetical protein
# protein_id=WP_019742709.1
# transl_table=11
# ID=gene-NMC_RS00410
# Name=NMC_RS00410
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00410
# old_locus_tag=NMC0073
# ID=cds-WP_002220129.1
# Parent=gene-NMC_RS00410
# Dbxref=GenBank:WP_002220129.1
# Name=WP_002220129.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002235352.1
# locus_tag=NMC_RS00410
# product=OmpP1/FadL family transporter
# protein_id=WP_002220129.1
# transl_table=11
# ID=gene-NMC_RS13440
# Name=NMC_RS13440
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS13440
# ID=cds-WP_002247729.1
# Parent=gene-NMC_RS13440
# Dbxref=GenBank:WP_002247729.1
# Name=WP_002247729.1
# gbkey=CDS
# inference=COORDINATES: ab initio prediction:GeneMarkS-2+
# locus_tag=NMC_RS13440
# product=hypothetical protein
# protein_id=WP_002247729.1
# transl_table=11
# ID=gene-NMC_RS00415
# Name=pyk
# gbkey=Gene
# gene=pyk
# gene_biotype=protein_coding
# locus_tag=NMC_RS00415
# old_locus_tag=NMC0074
# ID=cds-WP_002220131.1
# Parent=gene-NMC_RS00415
# Dbxref=GenBank:WP_002220131.1
# Name=WP_002220131.1
# Ontology_term=GO:0006096,GO:0004743,GO:0005737
# gbkey=CDS
# gene=pyk
# go_component=cytoplasm|0005737||IEA
# go_function=pyruvate kinase activity|0004743||IEA
# go_process=glycolytic process|0006096||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002218534.1
# locus_tag=NMC_RS00415
# product=pyruvate kinase
# protein_id=WP_002220131.1
# transl_table=11
# ID=gene-NMC_RS00420
# Name=NMC_RS00420
# end_range=90367,.
# gbkey=Gene
# gene_biotype=pseudogene
# locus_tag=NMC_RS00420
# old_locus_tag=NMC0075
# partial=true
# pseudo=true
# ID=cds-NMC_RS00420
# Parent=gene-NMC_RS00420
# Note=incomplete%3B partial in the middle of a contig%3B missing C-terminus
# end_range=90367,.
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_017805306.1
# locus_tag=NMC_RS00420
# partial=true
# product=transposase
# pseudo=true
# transl_table=11
# ID=gene-NMC_RS00425
# Name=NMC_RS00425
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00425
# old_locus_tag=NMC0080
# ID=cds-WP_002239409.1
# Parent=gene-NMC_RS00425
# Dbxref=GenBank:WP_002239409.1
# Name=WP_002239409.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002247730.1
# locus_tag=NMC_RS00425
# product=hypothetical protein
# protein_id=WP_002239409.1
# transl_table=11
# ID=gene-NMC_RS14160
# Name=NMC_RS14160
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS14160
# old_locus_tag=NMC0084
# ID=cds-WP_002232236.1
# Parent=gene-NMC_RS14160
# Dbxref=GenBank:WP_002232236.1
# Name=WP_002232236.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002232236.1
# locus_tag=NMC_RS14160
# product=hypothetical protein
# protein_id=WP_002232236.1
# transl_table=11
# ID=gene-NMC_RS00455
# Name=NMC_RS00455
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00455
# old_locus_tag=NMC0085
# ID=cds-WP_002220133.1
# Parent=gene-NMC_RS00455
# Dbxref=GenBank:WP_002220133.1
# Name=WP_002220133.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002220133.1
# locus_tag=NMC_RS00455
# product=HlyD family efflux transporter periplasmic adaptor subunit
# protein_id=WP_002220133.1
# transl_table=11
# ID=gene-NMC_RS00460
# Name=NMC_RS00460
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00460
# old_locus_tag=NMC0086
# ID=cds-WP_002220134.1
# Parent=gene-NMC_RS00460
# Dbxref=GenBank:WP_002220134.1
# Name=WP_002220134.1
# Ontology_term=GO:0005524,GO:0008233,GO:0016887,GO:0042626,GO:0140359,GO:0055052
# gbkey=CDS
# go_component=ATP-binding cassette (ABC) transporter complex%2C substrate-binding subunit-containing|0055052||IEA
# go_function=ATP binding|0005524||IEA,peptidase activity|0008233||IEA,ATP hydrolysis activity|0016887||IEA,ATPase-coupled transmembrane transporter activity|0042626||IEA,ABC-type transporter activity|0140359||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_003700725.1
# locus_tag=NMC_RS00460
# product=peptidase domain-containing ABC transporter
# protein_id=WP_002220134.1
# transl_table=11
# ID=gene-NMC_RS00470
# Name=NMC_RS00470
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00470
# old_locus_tag=NMC0088
# ID=cds-WP_002247924.1
# Parent=gene-NMC_RS00470
# Dbxref=GenBank:WP_002247924.1
# Name=WP_002247924.1
# Ontology_term=GO:0004803
# gbkey=CDS
# go_function=transposase activity|0004803||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_014581020.1
# locus_tag=NMC_RS00470
# product=IS5 family transposase
# protein_id=WP_002247924.1
# transl_table=11
# ID=gene-NMC_RS14625
# Name=NMC_RS14625
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS14625
# ID=cds-WP_139594186.1
# Parent=gene-NMC_RS14625
# Dbxref=GenBank:WP_139594186.1
# Name=WP_139594186.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_014575097.1
# locus_tag=NMC_RS14625
# product=hypothetical protein
# protein_id=WP_139594186.1
# transl_table=11
# ID=gene-NMC_RS11555
# Name=NMC_RS11555
# gbkey=Gene
# gene_biotype=pseudogene
# locus_tag=NMC_RS11555
# old_locus_tag=NMC0090
# pseudo=true
# ID=cds-NMC_RS11555
# Parent=gene-NMC_RS11555
# Note=frameshifted
# Ontology_term=GO:0004803
# gbkey=CDS
# go_function=transposase activity|0004803||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_021111752.1
# locus_tag=NMC_RS11555
# product=IS1595 family transposase
# pseudo=true
# transl_table=11
# ID=gene-NMC_RS00485
# Name=NMC_RS00485
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00485
# old_locus_tag=NMC0092
# ID=cds-WP_002220136.1
# Parent=gene-NMC_RS00485
# Dbxref=GenBank:WP_002220136.1
# Name=WP_002220136.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002216205.1
# locus_tag=NMC_RS00485
# product=hypothetical protein
# protein_id=WP_002220136.1
# transl_table=11
# ID=gene-NMC_RS00490
# Name=NMC_RS00490
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00490
# old_locus_tag=NMC0093
# ID=cds-WP_002240196.1
# Parent=gene-NMC_RS00490
# Dbxref=GenBank:WP_002240196.1
# Name=WP_002240196.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002255623.1
# locus_tag=NMC_RS00490
# product=C39 family peptidase
# protein_id=WP_002240196.1
# transl_table=11
# ID=gene-NMC_RS00500
# Name=NMC_RS00500
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00500
# old_locus_tag=NMC0095
# ID=cds-WP_002216208.1
# Parent=gene-NMC_RS00500
# Dbxref=GenBank:WP_002216208.1
# Name=WP_002216208.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002216208.1
# locus_tag=NMC_RS00500
# product=hypothetical protein
# protein_id=WP_002216208.1
# transl_table=11
# ID=gene-NMC_RS14320
# Name=NMC_RS14320
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS14320
# old_locus_tag=NMC0096
# ID=cds-WP_002220137.1
# Parent=gene-NMC_RS14320
# Dbxref=GenBank:WP_002220137.1
# Name=WP_002220137.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002223287.1
# locus_tag=NMC_RS14320
# product=hypothetical protein
# protein_id=WP_002220137.1
# transl_table=11
# ID=gene-NMC_RS00510
# Name=NMC_RS00510
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00510
# old_locus_tag=NMC0097
# ID=cds-WP_002216212.1
# Parent=gene-NMC_RS00510
# Dbxref=GenBank:WP_002216212.1
# Name=WP_002216212.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002216212.1
# locus_tag=NMC_RS00510
# product=GNAT family N-acetyltransferase
# protein_id=WP_002216212.1
# transl_table=11
# ID=gene-NMC_RS00515
# Name=pyrB
# gbkey=Gene
# gene=pyrB
# gene_biotype=protein_coding
# locus_tag=NMC_RS00515
# old_locus_tag=NMC0098
# ID=cds-WP_002216214.1
# Parent=gene-NMC_RS00515
# Dbxref=GenBank:WP_002216214.1
# Name=WP_002216214.1
# Ontology_term=GO:0009220,GO:0004070
# gbkey=CDS
# gene=pyrB
# go_function=aspartate carbamoyltransferase activity|0004070||IEA
# go_process=pyrimidine ribonucleotide biosynthetic process|0009220||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_003677959.1
# locus_tag=NMC_RS00515
# product=aspartate carbamoyltransferase
# protein_id=WP_002216214.1
# transl_table=11
# ID=gene-NMC_RS00520
# Name=pyrI
# gbkey=Gene
# gene=pyrI
# gene_biotype=protein_coding
# locus_tag=NMC_RS00520
# old_locus_tag=NMC0099
# ID=cds-WP_002216215.1
# Parent=gene-NMC_RS00520
# Dbxref=GenBank:WP_002216215.1
# Name=WP_002216215.1
# Ontology_term=GO:0009220,GO:0004070
# gbkey=CDS
# gene=pyrI
# go_function=aspartate carbamoyltransferase activity|0004070||IEA
# go_process=pyrimidine ribonucleotide biosynthetic process|0009220||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002245387.1
# locus_tag=NMC_RS00520
# product=aspartate carbamoyltransferase regulatory subunit
# protein_id=WP_002216215.1
# transl_table=11
# ID=gene-NMC_RS00525
# Name=NMC_RS00525
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00525
# old_locus_tag=NMC0100
# ID=cds-WP_002216216.1
# Parent=gene-NMC_RS00525
# Dbxref=GenBank:WP_002216216.1
# Name=WP_002216216.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_019273228.1
# locus_tag=NMC_RS00525
# product=hypothetical protein
# protein_id=WP_002216216.1
# transl_table=11
# ID=gene-NMC_RS00530
# Name=NMC_RS00530
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS00530
# old_locus_tag=NMC0101
# ID=cds-WP_002216217.1
# Parent=gene-NMC_RS00530
# Dbxref=GenBank:WP_002216217.1
# Name=WP_002216217.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002221827.1
# locus_tag=NMC_RS00530
# product=LysM peptidoglycan-binding domain-containing protein
# protein_id=WP_002216217.1
# transl_table=11
# ID=gene-NMC_RS00540
# Name=def
# gbkey=Gene
# gene=def
# gene_biotype=protein_coding
# locus_tag=NMC_RS00540
# old_locus_tag=NMC0102
# ID=cds-WP_002216218.1
# Parent=gene-NMC_RS00540
# Dbxref=GenBank:WP_002216218.1
# Name=WP_002216218.1
# Ontology_term=GO:0036211,GO:0042586
# gbkey=CDS
# gene=def
# go_function=peptide deformylase activity|0042586||IEA
# go_process=protein modification process|0036211||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_009312688.1
# locus_tag=NMC_RS00540
# product=peptide deformylase
# protein_id=WP_002216218.1
# transl_table=11
# ID=gene-NMC_RS00545
# Name=fmt
# gbkey=Gene
# gene=fmt
# gene_biotype=protein_coding
# locus_tag=NMC_RS00545
# old_locus_tag=NMC0103
# ID=cds-WP_002218547.1
# Parent=gene-NMC_RS00545
# Dbxref=GenBank:WP_002218547.1
# Name=WP_002218547.1
# Ontology_term=GO:0006431,GO:0004479,GO:0005737
# gbkey=CDS
# gene=fmt
# go_component=cytoplasm|0005737||IEA
# go_function=methionyl-tRNA formyltransferase activity|0004479||IEA
# go_process=methionyl-tRNA aminoacylation|0006431||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_012222146.1
# locus_tag=NMC_RS00545
# product=methionyl-tRNA formyltransferase
# protein_id=WP_002218547.1
# transl_table=11
# ID=gene-NMC_RS00550
# Name=rsmB
# gbkey=Gene
# gene=rsmB
# gene_biotype=protein_coding
# locus_tag=NMC_RS00550
# old_locus_tag=NMC0104
# ID=cds-WP_002220138.1
# ...
# locus_tag=NMC_RS11240
# product=surface-adhesin E family protein
# protein_id=WP_003688111.1
# transl_table=11
# ID=gene-NMC_RS11245
# Name=NMC_RS11245
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11245
# old_locus_tag=NMC2125
# ID=cds-WP_002216744.1-8
# Parent=gene-NMC_RS11245
# Dbxref=GenBank:WP_002216744.1
# Name=WP_002216744.1
# Ontology_term=GO:0006313,GO:0004803
# gbkey=CDS
# go_function=transposase activity|0004803||IEA
# go_process=DNA transposition|0006313||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002247434.1
# locus_tag=NMC_RS11245
# product=IS30-like element IS1655 family transposase
# protein_id=WP_002216744.1
# transl_table=11
# ID=gene-NMC_RS14150
# Name=NMC_RS14150
# gbkey=Gene
# gene_biotype=pseudogene
# locus_tag=NMC_RS14150
# partial=true
# pseudo=true
# start_range=.,2168494
# ID=cds-NMC_RS14150
# Parent=gene-NMC_RS14150
# Note=incomplete%3B partial in the middle of a contig%3B missing C-terminus
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_003688109.1
# locus_tag=NMC_RS14150
# partial=true
# product=hypothetical protein
# pseudo=true
# start_range=.,2168494
# transl_table=11
# ID=gene-NMC_RS11255
# Name=NMC_RS11255
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11255
# old_locus_tag=NMC2126
# ID=cds-WP_002221738.1
# Parent=gene-NMC_RS11255
# Dbxref=GenBank:WP_002221738.1
# Name=WP_002221738.1
# Ontology_term=GO:0006313,GO:0004803
# gbkey=CDS
# go_function=transposase activity|0004803||IEA
# go_process=DNA transposition|0006313||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_076611451.1
# locus_tag=NMC_RS11255
# product=IS1595-like element IS1016C family transposase
# protein_id=WP_002221738.1
# transl_table=11
# ID=gene-NMC_RS11260
# Name=NMC_RS11260
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11260
# old_locus_tag=NMC2128
# ID=cds-WP_002221739.1
# Parent=gene-NMC_RS11260
# Dbxref=GenBank:WP_002221739.1
# Name=WP_002221739.1
# Ontology_term=GO:0000166,GO:0003725,GO:0005524,GO:0061710
# gbkey=CDS
# go_function=nucleotide binding|0000166||IEA,double-stranded RNA binding|0003725||IEA,ATP binding|0005524||IEA,L-threonylcarbamoyladenylate synthase|0061710||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002255407.1
# locus_tag=NMC_RS11260
# product=L-threonylcarbamoyladenylate synthase
# protein_id=WP_002221739.1
# transl_table=11
# ID=gene-NMC_RS11265
# Name=purD
# gbkey=Gene
# gene=purD
# gene_biotype=protein_coding
# locus_tag=NMC_RS11265
# old_locus_tag=NMC2129
# ID=cds-WP_002221740.1
# Parent=gene-NMC_RS11265
# Dbxref=GenBank:WP_002221740.1
# Name=WP_002221740.1
# Ontology_term=GO:0006189,GO:0009152,GO:0004637
# gbkey=CDS
# gene=purD
# go_function=phosphoribosylamine-glycine ligase activity|0004637||IEA
# go_process='de novo' IMP biosynthetic process|0006189||IEA,purine ribonucleotide biosynthetic process|0009152||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_012222175.1
# locus_tag=NMC_RS11265
# product=phosphoribosylamine--glycine ligase
# protein_id=WP_002221740.1
# transl_table=11
# ID=gene-NMC_RS11270
# Name=NMC_RS11270
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11270
# old_locus_tag=NMC2130
# ID=cds-WP_002215166.1
# Parent=gene-NMC_RS11270
# Dbxref=GenBank:WP_002215166.1
# Name=WP_002215166.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_019270242.1
# locus_tag=NMC_RS11270
# product=DUF4298 domain-containing protein
# protein_id=WP_002215166.1
# transl_table=11
# ID=gene-NMC_RS11275
# Name=NMC_RS11275
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11275
# old_locus_tag=NMC2131
# ID=cds-WP_002221741.1
# Parent=gene-NMC_RS11275
# Dbxref=GenBank:WP_002221741.1
# Name=WP_002221741.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002224205.1
# locus_tag=NMC_RS11275
# product=YigZ family protein
# protein_id=WP_002221741.1
# transl_table=11
# ID=gene-NMC_RS11280
# Name=NMC_RS11280
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11280
# old_locus_tag=NMC2132
# ID=cds-WP_002221742.1
# Parent=gene-NMC_RS11280
# Dbxref=GenBank:WP_002221742.1
# Name=WP_002221742.1
# Ontology_term=GO:0009055,GO:0050660
# gbkey=CDS
# go_function=electron transfer activity|0009055||IEA,flavin adenine dinucleotide binding|0050660||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002249544.1
# locus_tag=NMC_RS11280
# product=electron transfer flavoprotein subunit alpha/FixB family protein
# protein_id=WP_002221742.1
# transl_table=11
# ID=gene-NMC_RS11285
# Name=NMC_RS11285
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11285
# old_locus_tag=NMC2133
# ID=cds-WP_002221743.1
# Parent=gene-NMC_RS11285
# Dbxref=GenBank:WP_002221743.1
# Name=WP_002221743.1
# Ontology_term=GO:0009055
# gbkey=CDS
# go_function=electron transfer activity|0009055||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_004519189.1
# locus_tag=NMC_RS11285
# product=electron transfer flavoprotein subunit beta/FixA family protein
# protein_id=WP_002221743.1
# transl_table=11
# ID=gene-NMC_RS11290
# Name=waaC
# gbkey=Gene
# gene=waaC
# gene_biotype=protein_coding
# locus_tag=NMC_RS11290
# old_locus_tag=NMC2134
# ID=cds-WP_002221745.1
# Parent=gene-NMC_RS11290
# Dbxref=GenBank:WP_002221745.1
# Name=WP_002221745.1
# Ontology_term=GO:0009244,GO:0008920
# gbkey=CDS
# gene=waaC
# go_function=lipopolysaccharide heptosyltransferase activity|0008920||IEA
# go_process=lipopolysaccharide core region biosynthetic process|0009244||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002218264.1
# locus_tag=NMC_RS11290
# product=lipopolysaccharide heptosyltransferase I
# protein_id=WP_002221745.1
# transl_table=11
# ID=gene-NMC_RS11295
# Name=NMC_RS11295
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11295
# old_locus_tag=NMC2135
# ID=cds-WP_002221746.1
# Parent=gene-NMC_RS11295
# Dbxref=GenBank:WP_002221746.1
# Name=WP_002221746.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002220020.1
# locus_tag=NMC_RS11295
# product=nicotinamidase
# protein_id=WP_002221746.1
# transl_table=11
# ID=gene-NMC_RS11300
# Name=tsaA
# gbkey=Gene
# gene=tsaA
# gene_biotype=protein_coding
# locus_tag=NMC_RS11300
# old_locus_tag=NMC2136
# ID=cds-WP_002221747.1
# Parent=gene-NMC_RS11300
# Dbxref=GenBank:WP_002221747.1
# Name=WP_002221747.1
# Ontology_term=GO:0006400,GO:0008757,GO:0005737
# gbkey=CDS
# gene=tsaA
# go_component=cytoplasm|0005737||IEA
# go_function=S-adenosylmethionine-dependent methyltransferase activity|0008757||IEA
# go_process=tRNA modification|0006400||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002218266.1
# locus_tag=NMC_RS11300
# product=tRNA (N6-threonylcarbamoyladenosine(37)-N6)-methyltransferase TrmO
# protein_id=WP_002221747.1
# transl_table=11
# ID=gene-NMC_RS11305
# Name=gap
# gbkey=Gene
# gene=gap
# gene_biotype=protein_coding
# locus_tag=NMC_RS11305
# old_locus_tag=NMC2137
# ID=cds-WP_002221748.1
# Parent=gene-NMC_RS11305
# Dbxref=GenBank:WP_002221748.1
# Name=WP_002221748.1
# Ontology_term=GO:0006094,GO:0006096,GO:0019682
# gbkey=CDS
# gene=gap
# go_process=gluconeogenesis|0006094||IEA,glycolytic process|0006096||IEA,glyceraldehyde-3-phosphate metabolic process|0019682||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_003766473.1
# locus_tag=NMC_RS11305
# product=type I glyceraldehyde-3-phosphate dehydrogenase
# protein_id=WP_002221748.1
# transl_table=11
# ID=gene-NMC_RS11310
# Name=mutS
# gbkey=Gene
# gene=mutS
# gene_biotype=protein_coding
# locus_tag=NMC_RS11310
# old_locus_tag=NMC2138
# ID=cds-WP_002215177.1
# Parent=gene-NMC_RS11310
# Dbxref=GenBank:WP_002215177.1
# Name=WP_002215177.1
# Ontology_term=GO:0006298,GO:0005524
# gbkey=CDS
# gene=mutS
# go_function=ATP binding|0005524||IEA
# go_process=mismatch repair|0006298||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_014575632.1
# locus_tag=NMC_RS11310
# product=DNA mismatch repair protein MutS
# protein_id=WP_002215177.1
# transl_table=11
# ID=gene-NMC_RS11315
# Name=NMC_RS11315
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11315
# old_locus_tag=NMC2139
# ID=cds-WP_002221749.1
# Parent=gene-NMC_RS11315
# Dbxref=GenBank:WP_002221749.1
# Name=WP_002221749.1
# Ontology_term=GO:0008080
# gbkey=CDS
# go_function=N-acetyltransferase activity|0008080||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002227776.1
# locus_tag=NMC_RS11315
# product=GNAT family N-acetyltransferase
# protein_id=WP_002221749.1
# transl_table=11
# ID=gene-NMC_RS11320
# Name=NMC_RS11320
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11320
# old_locus_tag=NMC2140
# ID=cds-WP_002221751.1
# Parent=gene-NMC_RS11320
# Dbxref=GenBank:WP_002221751.1
# Name=WP_002221751.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002215179.1
# locus_tag=NMC_RS11320
# product=hypothetical protein
# protein_id=WP_002221751.1
# transl_table=11
# ID=gene-NMC_RS11325
# Name=gltX
# gbkey=Gene
# gene=gltX
# gene_biotype=protein_coding
# locus_tag=NMC_RS11325
# old_locus_tag=NMC2141
# ID=cds-WP_002221752.1
# Parent=gene-NMC_RS11325
# Dbxref=GenBank:WP_002221752.1
# Name=WP_002221752.1
# Ontology_term=GO:0006424,GO:0004818,GO:0009332
# gbkey=CDS
# gene=gltX
# go_component=glutamate-tRNA ligase complex|0009332||IEA
# go_function=glutamate-tRNA ligase activity|0004818||IEA
# go_process=glutamyl-tRNA aminoacylation|0006424||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002246563.1
# locus_tag=NMC_RS11325
# product=glutamate--tRNA ligase
# protein_id=WP_002221752.1
# transl_table=11
# ID=gene-NMC_RS11330
# Name=NMC_RS11330
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11330
# old_locus_tag=NMC2142
# ID=cds-WP_002221753.1
# Parent=gene-NMC_RS11330
# Dbxref=GenBank:WP_002221753.1
# Name=WP_002221753.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_019271975.1
# locus_tag=NMC_RS11330
# product=YdcF family protein
# protein_id=WP_002221753.1
# transl_table=11
# ID=gene-NMC_RS11335
# Name=arsC
# gbkey=Gene
# gene=arsC
# gene_biotype=protein_coding
# locus_tag=NMC_RS11335
# old_locus_tag=NMC2143
# ID=cds-WP_002221754.1
# Parent=gene-NMC_RS11335
# Dbxref=GenBank:WP_002221754.1
# Name=WP_002221754.1
# Note=This arsenate reductase requires both glutathione and glutaredoxin to convert arsenate to arsenite%2C after which the efflux transporter formed by ArsA and ArsB can extrude the arsenite from the cell%2C providing resistance.
# Ontology_term=GO:0046685,GO:0008794
# gbkey=CDS
# gene=arsC
# go_function=arsenate reductase (glutaredoxin) activity|0008794||IEA
# go_process=response to arsenic-containing substance|0046685||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_019271974.1
# locus_tag=NMC_RS11335
# product=arsenate reductase (glutaredoxin)
# protein_id=WP_002221754.1
# transl_table=11
# ID=gene-NMC_RS11340
# Name=NMC_RS11340
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11340
# old_locus_tag=NMC2144
# ID=cds-WP_002224720.1
# Parent=gene-NMC_RS11340
# Dbxref=GenBank:WP_002224720.1
# Name=WP_002224720.1
# Ontology_term=GO:0016491
# gbkey=CDS
# go_function=oxidoreductase activity|0016491||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_003710797.1
# locus_tag=NMC_RS11340
# product=TlpA disulfide reductase family protein
# protein_id=WP_002224720.1
# transl_table=11
# ID=gene-NMC_RS11345
# Name=ftsE
# gbkey=Gene
# gene=ftsE
# gene_biotype=protein_coding
# locus_tag=NMC_RS11345
# old_locus_tag=NMC2145
# ID=cds-WP_002221756.1
# Parent=gene-NMC_RS11345
# Dbxref=GenBank:WP_002221756.1
# Name=WP_002221756.1
# Ontology_term=GO:0000910,GO:0005524
# gbkey=CDS
# gene=ftsE
# go_function=ATP binding|0005524||IEA
# go_process=cytokinesis|0000910||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002242116.1
# locus_tag=NMC_RS11345
# product=cell division ATP-binding protein FtsE
# protein_id=WP_002221756.1
# transl_table=11
# ID=gene-NMC_RS11350
# Name=ftsX
# gbkey=Gene
# gene=ftsX
# gene_biotype=protein_coding
# locus_tag=NMC_RS11350
# old_locus_tag=NMC2146
# ID=cds-WP_002221758.1
# Parent=gene-NMC_RS11350
# Dbxref=GenBank:WP_002221758.1
# Name=WP_002221758.1
# Ontology_term=GO:0000910
# gbkey=CDS
# gene=ftsX
# go_process=cytokinesis|0000910||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_003688074.1
# locus_tag=NMC_RS11350
# product=permease-like cell division protein FtsX
# protein_id=WP_002221758.1
# transl_table=11
# ID=gene-NMC_RS11355
# Name=NMC_RS11355
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11355
# old_locus_tag=NMC2147
# ID=cds-WP_002221759.1
# Parent=gene-NMC_RS11355
# Dbxref=GenBank:WP_002221759.1
# Name=WP_002221759.1
# Ontology_term=GO:0051537,GO:1990229
# gbkey=CDS
# go_component=iron-sulfur cluster assembly complex|1990229||IEA
# go_function=2 iron%2C 2 sulfur cluster binding|0051537||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002218280.1
# locus_tag=NMC_RS11355
# product=BolA family protein
# protein_id=WP_002221759.1
# transl_table=11
# ID=gene-NMC_RS11360
# Name=NMC_RS11360
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11360
# old_locus_tag=NMC2148
# ID=cds-WP_002221761.1
# Parent=gene-NMC_RS11360
# Dbxref=GenBank:WP_002221761.1
# Name=WP_002221761.1
# Ontology_term=GO:0006096,GO:0004618,GO:0005524,GO:0005737
# gbkey=CDS
# go_component=cytoplasm|0005737||IEA
# go_function=phosphoglycerate kinase activity|0004618||IEA,ATP binding|0005524||IEA
# go_process=glycolytic process|0006096||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_014573670.1
# locus_tag=NMC_RS11360
# product=phosphoglycerate kinase
# protein_id=WP_002221761.1
# transl_table=11
# ID=gene-NMC_RS11365
# Name=murA
# gbkey=Gene
# gene=murA
# gene_biotype=protein_coding
# locus_tag=NMC_RS11365
# old_locus_tag=NMC2149
# ID=cds-WP_002221762.1
# Parent=gene-NMC_RS11365
# Dbxref=GenBank:WP_002221762.1
# Name=WP_002221762.1
# Ontology_term=GO:0009252,GO:0008760
# gbkey=CDS
# gene=murA
# go_function=UDP-N-acetylglucosamine 1-carboxyvinyltransferase activity|0008760||IEA
# go_process=peptidoglycan biosynthetic process|0009252||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_012221092.1
# locus_tag=NMC_RS11365
# product=UDP-N-acetylglucosamine 1-carboxyvinyltransferase
# protein_id=WP_002221762.1
# transl_table=11
# ID=gene-NMC_RS11370
# Name=NMC_RS11370
# gbkey=Gene
# gene_biotype=tRNA
# locus_tag=NMC_RS11370
# old_locus_tag=NMC_t59
# ID=rna-NMC_RS11370
# Parent=gene-NMC_RS11370
# anticodon=(pos:complement(2190447..2190449))
# gbkey=tRNA
# inference=COORDINATES: profile:tRNAscan-SE:2.0.12
# locus_tag=NMC_RS11370
# product=tRNA-Lys
# ID=exon-NMC_RS11370-1
# Parent=rna-NMC_RS11370
# anticodon=(pos:complement(2190447..2190449))
# gbkey=tRNA
# inference=COORDINATES: profile:tRNAscan-SE:2.0.12
# locus_tag=NMC_RS11370
# product=tRNA-Lys
# ID=gene-NMC_RS11375
# Name=NMC_RS11375
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11375
# old_locus_tag=NMC2150
# ID=cds-WP_002221763.1
# Parent=gene-NMC_RS11375
# Dbxref=GenBank:WP_002221763.1
# Name=WP_002221763.1
# Ontology_term=GO:0016020
# gbkey=CDS
# go_component=membrane|0016020||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_003697776.1
# locus_tag=NMC_RS11375
# product=TerC family protein
# protein_id=WP_002221763.1
# transl_table=11
# ID=gene-NMC_RS11380
# Name=NMC_RS11380
# gbkey=Gene
# gene_biotype=protein_coding
# locus_tag=NMC_RS11380
# old_locus_tag=NMC2151
# ID=cds-WP_002221764.1
# Parent=gene-NMC_RS11380
# Dbxref=GenBank:WP_002221764.1
# Name=WP_002221764.1
# gbkey=CDS
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002221764.1
# locus_tag=NMC_RS11380
# product=CopD family copper resistance protein
# protein_id=WP_002221764.1
# transl_table=11
# ID=gene-NMC_RS11385
# Name=waaA
# gbkey=Gene
# gene=waaA
# gene_biotype=protein_coding
# locus_tag=NMC_RS11385
# old_locus_tag=NMC2152
# ID=cds-WP_041423265.1
# Parent=gene-NMC_RS11385
# Dbxref=GenBank:WP_041423265.1
# Name=WP_041423265.1
# Ontology_term=GO:0016740
# gbkey=CDS
# gene=waaA
# go_function=transferase activity|0016740||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_002223244.1
# locus_tag=NMC_RS11385
# product=lipid IV(A) 3-deoxy-D-manno-octulosonic acid transferase
# protein_id=WP_041423265.1
# transl_table=11
# ID=gene-NMC_RS11390
# Name=gnd
# gbkey=Gene
# gene=gnd
# gene_biotype=protein_coding
# locus_tag=NMC_RS11390
# old_locus_tag=NMC2153
# ID=cds-WP_002221767.1
# Parent=gene-NMC_RS11390
# Dbxref=GenBank:WP_002221767.1
# Name=WP_002221767.1
# Ontology_term=GO:0006098,GO:0004616,GO:0005737
# gbkey=CDS
# gene=gnd
# go_component=cytoplasm|0005737||IEA
# go_function=phosphogluconate dehydrogenase (decarboxylating) activity|0004616||IEA
# go_process=pentose-phosphate shunt|0006098||IEA
# inference=COORDINATES: similar to AA sequence:RefSeq:WP_019269816.1
# locus_tag=NMC_RS11390
# product=decarboxylating NADP(+)-dependent phosphogluconate dehydrogenase
# protein_id=WP_002221767.1
# transl_table=11

# %%
len(gff_data), gff_data["country"].isna().sum()
# Out:
# (4453, np.int64(4452))

# %%
len(gff_data), gff_data["genome"].isna().sum()
# Out:
# (4453, np.int64(4452))

# %%
len(gff_data), gff_data["regulatory_class"].isna().sum()
# Out:
# (4453, np.int64(4448))

# %%
len(gff_data), gff_data["mol_type"].isna().sum()
# Out:
# (4453, np.int64(4452))

# %%
len(gff_data), gff_data["bound_moiety"].isna().sum()
# Out:
# (4453, np.int64(4448))

# %%
len(gff_data), gff_data["serotype"].isna().sum()
# Out:
# (4453, np.int64(4452))

# %%
len(gff_data), gff_data["exception"].isna().sum()
# Out:
# (4453, np.int64(4451))

# %%
len(gff_data), gff_data["gene_synonym"].isna().sum()
# Out:
# (4453, np.int64(4448))

# %%
gff_data.drop(columns=['attributes', "Dbxref", "score",
                       "country", "genome",
                       "regulatory_class", "mol_type",
                       "bound_moiety", "serotype",
                       "exception", "gene_synonym"], inplace=True)

# %%
gff_data['Is_Complement'] = gff_data['strand'].map({'+': True, '-': False})
gff_data.drop(columns=['strand'], inplace=True)
# Map "true" to True and "false" to False
gff_data['Is_circular'] = gff_data['Is_circular'].map({'true': True, 'false': False})
# Replace NaN values with False
gff_data['Is_circular'] = gff_data['Is_circular'].fillna(False)
gff_data["partial"] = gff_data["partial"].fillna(False)
# Out:
# /var/folders/24/jbn800492ks0n353ktq87jp00000gn/T/ipykernel_73615/3283839227.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   gff_data['Is_circular'] = gff_data['Is_circular'].fillna(False)

# %%
gff_data.columns
# Out:
# Index(['seqid', 'source', 'type', 'start', 'end', 'phase', 'Is_circular',
#        'Name', 'gbkey', 'strain', 'gene', 'gene_biotype', 'locus_tag',
#        'old_locus_tag', 'Parent', 'Ontology_term', 'go_function', 'go_process',
#        'inference', 'product', 'protein_id', 'transl_table', 'end_range',
#        'partial', 'pseudo', 'Note', 'start_range', 'go_component', 'anticodon',
#        'seq_type', 'Chromosome', 'Chromosome_ID', 'Region_Start', 'Region_End',
#        'Is_Complement'],
#       dtype='object')

# %%
gff_data
# Out:
#             seqid            source        type    start      end phase  \
# 0     NC_008767.1            RefSeq      region        1  2194961     .
# 1     NC_008767.1            RefSeq        gene     1261     2184     .
# 2     NC_008767.1  Protein Homology         CDS     1261     2184     0
# 3     NC_008767.1            RefSeq  pseudogene     3341     3610     .
# 4     NC_008767.1  Protein Homology         CDS     3341     3610     0
# ...           ...               ...         ...      ...      ...   ...
# 4448  NC_008767.1  Protein Homology         CDS  2191558  2192007     0
# 4449  NC_008767.1            RefSeq        gene  2192048  2193319     .
# 4450  NC_008767.1  Protein Homology         CDS  2192048  2193319     0
# 4451  NC_008767.1            RefSeq        gene  2193382  2194830     .
# 4452  NC_008767.1  Protein Homology         CDS  2193382  2194830     0
#
#       Is_circular            Name gbkey strain  ...  \
# 0            True       ANONYMOUS   Src  FAM18  ...
# 1           False            lpxC  Gene    NaN  ...
# 2           False  WP_002220060.1   CDS    NaN  ...
# 3           False     NMC_RS00015  Gene    NaN  ...
# 4           False             NaN   CDS    NaN  ...
# ...           ...             ...   ...    ...  ...
# 4448        False  WP_002221764.1   CDS    NaN  ...
# 4449        False            waaA  Gene    NaN  ...
# 4450        False  WP_041423265.1   CDS    NaN  ...
# 4451        False             gnd  Gene    NaN  ...
# 4452        False  WP_002221767.1   CDS    NaN  ...
#
#                                                    Note start_range  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4     incomplete%3B partial in the middle of a conti...         NaN
# ...                                                 ...         ...
# 4448                                                NaN         NaN
# 4449                                                NaN         NaN
# 4450                                                NaN         NaN
# 4451                                                NaN         NaN
# 4452                                                NaN         NaN
#
#                 go_component anticodon seq_type    Chromosome Chromosome_ID  \
# 0                        NaN       NaN     None     NC_008767             1
# 1                        NaN       NaN     gene   NMC_RS00010          None
# 2                        NaN       NaN      cds  WP_002220060             1
# 3                        NaN       NaN     gene   NMC_RS00015          None
# 4                        NaN       NaN      cds   NMC_RS00015          None
# ...                      ...       ...      ...           ...           ...
# 4448                     NaN       NaN      cds  WP_002221764             1
# 4449                     NaN       NaN     gene   NMC_RS11385          None
# 4450                     NaN       NaN      cds  WP_041423265             1
# 4451                     NaN       NaN     gene   NMC_RS11390          None
# 4452  cytoplasm|0005737||IEA       NaN      cds  WP_002221767             1
#
#      Region_Start Region_End Is_Complement
# 0               1    2194961          True
# 1            None       None         False
# 2            None       None         False
# 3            None       None         False
# 4            None       None         False
# ...           ...        ...           ...
# 4448         None       None         False
# 4449         None       None         False
# 4450         None       None         False
# 4451         None       None         False
# 4452         None       None         False
#
# [4453 rows x 35 columns]
